# %% [markdown]
# **Кулешов Иван AML-14**

# %% [markdown]
# Большая часть содержимого ноутбука выдана преподавателем на лекции. Что добавлено и сделано:
# - Добавлена разметка для рыб категории OTHER и перевод в json
# - Добавлена разметка категории NoF
# - Функция потерь для классификации
# - Разделение обучающей выборки на тренировочную и валидационную
# - Проведено обучение сети (10 эпох с дообучением 10 эпох)
# - Функция для формирования сабмит-файла csv

# %% [markdown]
# # Домашнее задание «Задачи детекции и сегментации»

# %% [markdown]
# В данном задании вам предстоит помочь The Nature Conservancy в борьбе с рыбаками-браконьерами. Необходимо по снимкам с камеры на рыболовецком судне классифицировать улов.

# %% [markdown]
# # The Nature Conservancy Fisheries Monitoring

# %% [markdown]
# Домашнее задание к занятию «Задачи детекции и сегментации».
#
# В данном задании вам предстоит помочь The Nature Conservancy в борьбе с рыбаками-браконьерами.
# Необходимо по снимкам с камеры на рыболовецком судне классифицировать улов. За основу решения предлагается взять модель детектора:
# [github.com...tion.ipynb](https://github.com/a4tunado/lectures/blob/master/007/007-detection.ipynb). Решение необходимо прислать в виде ссылки на ipython-ноутбук с указанием значения метрики на Leaderboard.

# %% [markdown]
# https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tqdm.notebook import tqdm
import zipfile
from scipy.special import softmax
from matplotlib import pyplot as plt

# !pip install py7zr

# %% [markdown]
# # Загружаем разметку

# %% [markdown]
# ⛏ Всю разработку будем вести в google Colab - подключаем Гугл.Диск и распаковываем в рабочую область исходные данные

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with zipfile.ZipFile("/content/drive/MyDrive/fish/train.zip","r") as z:
    z.extractall(".")

# %% [markdown]
# ---

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = 'train'
BOXES_PATH = '/content/drive/MyDrive/fish/boxes/'

def load_annotations():
    boxes = dict()
    for path in tqdm(glob(BOXES_PATH + '*.json')):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            for annotation in json.load(src):
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(
                    TRAIN_PREFIX, label.upper(), basename)
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
                    rect['class'] = label
                if os.path.isfile(annotation['filename']):
                    boxes.setdefault(label, []).append(annotation)
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for i, rect in enumerate(rectangles):
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=10)
            img = cv2.putText(img.copy(), annotation['annotations'][i]['class'], tuple(np.array(pt1)+[0,-7]), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 4 )
        return img
    
    def __draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for i, rect in enumerate(rectangles):
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=3)
            img = cv2.putText(img.copy(), counts['class'][int(rect['label'])] + ': ' + str(rect['label']), tuple(np.array(pt1)+[0,-7]), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 4 )
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation.get('annotations', []), scale_x, scale_y)
    
    if rectangles is not None:
        img = __draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_annotations()  # загружаем разметку детекций
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
counts = pd.DataFrame(
    [(k, len(v)) for k, v in boxes.items()],
    columns=['class', 'count']).sort_values(by='count', ascending=False).reset_index()

fish_classes = counts['class'].values
print(fish_classes)
counts
# Out:
# ['alb' 'yft' 'nof' 'other' 'bet' 'shark' 'dol' 'lag']
#    index  class  count
# 0      5    alb   1719
# 1      2    yft    734
# 2      7    nof    465
# 3      6  other    299
# 4      0    bet    200
# 5      4  shark    176
# 6      3    dol    117
# 7      1    lag     67

# %%
# Легенда классификации рыб будет выглядеть так:
# class 0: alb - Albacore tuna 
# class 1: yft - Yellowfin tuna
# class 2: nof - No Fishes (на фото нет никаких рыб)
# class 3: oth - Other Fishes (на фото другие рыбы, не относящиеся ни к одному другому классу)
# class 4: bet - Bigeye tuna
# class 5: shark - Sharks
# class 6: dol - Dolphinfish (Mahi Mahi)
# class 7: lag - Opah, Moonfish (Lamprus Guttatus)

# %% [markdown]
# ⛏ Выведем пример разметки для разных классов, включая класс OTHER (раз уж выданный для задания ноутбук содержит почти всё, надо хоть что-то сделать, например, разметку OTHER)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(8, 12), dpi=120)
boxes_ = [boxes['other'][3],boxes['other'][4],boxes['alb'][0],boxes['bet'][0],boxes['dol'][0],boxes['lag'][0],
         boxes['shark'][0], boxes['yft'][0]]

for i, box in enumerate(boxes_, 1):
    img = draw_boxes(box)
    subplot = fig.add_subplot(4, 2, i)
    subplot.set_title('{} {}x{}'.format(box['filename'], img.shape[0], img.shape[1]))
    plt.imshow(img);

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                   for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
from tensorflow.keras.applications import vgg16

IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = vgg16.VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
    
feature_tensor = features.layers[-1].output
print(feature_tensor.shape)
# Out:
# (None, 23, 37, 512)

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])
print(FEATURE_SHAPE)

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

# сетка якорей, размер определяется соотношением 
# размера входного изображения и размером тензора признаков
ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]
# Out:
# (23, 37)

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 13), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        label = fish_classes == rect['class']
                
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]
            
        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = np.array([*label, 1., dx, dy, dw, dh])

    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            
            label = np.empty(len(fish_classes))
            
            *label, digit, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(digit)
            label = softmax(label)

            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf,
                                   'label': np.argmax(_sigmoid(label)),
                                   'labels': label })
    return rectangles

def non_max_suppression(rectangles, max_output_size, iou_threshold=0.5):
    if not rectangles:
        return rectangles
    
    boxes = [[r['y'],
              r['x'],
              r['y'] + r['height'],
              r['x'] + r['width']] for r in rectangles]
    scores = [r['conf'] for r in rectangles]
    indices = tf.image.non_max_suppression(np.array(boxes),
                                           np.array(scores),
                                           max_output_size,
                                           iou_threshold)
    
    return [rectangles[i] for i in indices]

# %% [markdown]
# ### Валидация энкодинга/декодинга якорей

# %%
annotation = boxes['other'][3]

encoded = encode_anchors(annotation,
                         img_shape=(IMG_HEIGHT, IMG_WIDTH),
                         iou_thr=0.1)

decoded = decode_prediction(encoded, conf_thr=0.7)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(annotation, decoded))
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ## Функция потерь

# %%
num_classes = len(fish_classes)

K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    
    conf_loss = K.binary_crossentropy(y_true[..., num_classes], 
                                      y_pred[..., num_classes],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., num_classes + 1:] - y_pred[..., num_classes + 1:])
    square_loss = 0.5 * K.square(y_true[..., num_classes + 1:] - y_pred[..., num_classes + 1:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)


def class_loss(y_tr, y_pr, alpha=0.25, gamma=2.0):
    
    y_true = y_tr[..., :num_classes]
    y_pred = y_pr[..., :num_classes]

    cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
        labels=y_true, logits=y_pred
    )
    probs = tf.nn.softmax(y_pred)
    alpha = tf.where(tf.equal(y_true, 1.0), alpha, (1.0 - alpha))
    pt = tf.where(tf.equal(y_true, 1.0), probs, 1 - probs)
    loss = alpha * tf.pow(1.0 - pt, gamma) * cross_entropy
    
    return tf.reduce_sum(loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    y_true = K.reshape(y_true, (batch_size, -1, num_classes + 5))
    y_pred = K.reshape(y_pred, (batch_size, -1, num_classes + 5))
    
    # TODO: добавьте функцию потерь для классификации детекции
    classification_loss = class_loss(y_true, y_pred)

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)

    # positive examples loss
    pos_class_loss = K.sum(classification_loss * y_true[..., num_classes], axis=-1)
    pos_conf_loss = K.sum(conf_loss * y_true[..., num_classes], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., num_classes], axis=-1)

    # negative examples loss
    anchors = K.shape(y_true)[1]

    num_pos = K.sum(y_true[..., num_classes], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., num_classes]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    classification_loss = pos_class_loss / (num_pos + 1e-32)
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
   
    return total_conf_loss + 0.5 * loc_loss + classification_loss

# %% [markdown]
# ## Загрузка данных

# %%
from random import shuffle

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, vgg16.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

def train_generator(boxes, batch_size=32):
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

def val_generator(boxes, batch_size=32):
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = tf.keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
output = tf.keras.layers.Conv2D(num_classes + 5,
                                kernel_size=(1, 1), 
                                activation='linear',
                                kernel_regularizer='l2')(output)

model = tf.keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 750, 1200, 3)]    0
#
#  block1_conv1 (Conv2D)       (None, 750, 1200, 64)     1792
#
#  block1_conv2 (Conv2D)       (None, 750, 1200, 64)     36928
#
#  block1_pool (MaxPooling2D)  (None, 375, 600, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 375, 600, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 375, 600, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 187, 300, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 187, 300, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 93, 150, 256)      0
#
#  block4_conv1 (Conv2D)       (None, 93, 150, 512)      1180160
#
#  block4_conv2 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_conv3 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_pool (MaxPooling2D)  (None, 46, 75, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 23, 37, 512)       0
#
#  batch_normalization_1 (Batc  (None, 23, 37, 512)      2048
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 23, 37, 13)        6669
#
# =================================================================
# Total params: 14,723,405
# Trainable params: 7,087,117
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %% [markdown]
# ## Обучение

# %% [markdown]
# ⛏Разбиваем на трейн и валидацию

# %%
val_filename = []
for fish_cls in fish_classes:
  fish_num = int(len(boxes[fish_cls]) * 0.2)

  boxes1 = boxes[fish_cls][-fish_num:]
  for box in boxes1:
    val_filename.append(box['filename'])
  
boxes1 = sum(boxes.values(), [])
boxes_train = list(filter(lambda x: x['filename'] not in val_filename, boxes1))
boxes_val = list(filter(lambda x: x['filename'] in val_filename, boxes1))

# %%
lr =1e-5
BATCH_SIZE = 5
EPOCHS = 10

# %%
def lr_exp_decay(epoch, lr):
    k = 0.5
    #return lr * np.exp(-k*epoch)
    return lr / 2**epoch

optimizer = tf.keras.optimizers.Adam(learning_rate=lr, decay=1e-6)
model.compile(optimizer=optimizer, 
              loss=total_loss,
              metrics=[confidence_loss, class_loss, smooth_l1])


gen = data_generator(boxes, batch_size=BATCH_SIZE)
steps_per_epoch = sum(map(len, boxes.values()), 0) / BATCH_SIZE

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/fish/fishdetector_wh_val.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=True,
    mode='auto',
    save_freq=50)

# %%
history = model.fit(
          train_generator(boxes_train, batch_size=BATCH_SIZE), 
          steps_per_epoch=len(boxes_train) / BATCH_SIZE,
          epochs=EPOCHS,
          validation_data=val_generator(boxes_val, batch_size=BATCH_SIZE),
          validation_steps=len(boxes_val) / BATCH_SIZE,
          callbacks=[checkpoint]) #, tf.keras.callbacks.LearningRateScheduler(lr_exp_decay, verbose=1)])
# Out:
# Epoch 1/10
#  49/605 [=>............................] - ETA: 5:57 - loss: 0.1503 - confidence_loss: 0.0072 - class_loss: 0.1224 - smooth_l1: 1.0626
# Epoch 1: loss improved from inf to 0.14926, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
#  99/605 [===>..........................] - ETA: 5:34 - loss: 0.1460 - confidence_loss: 0.0072 - class_loss: 0.1230 - smooth_l1: 1.0659
# Epoch 1: loss improved from 0.14926 to 0.14647, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 149/605 [======>.......................] - ETA: 5:01 - loss: 0.1414 - confidence_loss: 0.0071 - class_loss: 0.1237 - smooth_l1: 1.0636
# Epoch 1: loss improved from 0.14647 to 0.14128, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 199/605 [========>.....................] - ETA: 4:29 - loss: 0.1434 - confidence_loss: 0.0072 - class_loss: 0.1242 - smooth_l1: 1.0627
# Epoch 1: loss did not improve from 0.14128
# 249/605 [===========>..................] - ETA: 3:55 - loss: 0.1427 - confidence_loss: 0.0071 - class_loss: 0.1245 - smooth_l1: 1.0627
# Epoch 1: loss did not improve from 0.14128
# 299/605 [=============>................] - ETA: 3:22 - loss: 0.1398 - confidence_loss: 0.0071 - class_loss: 0.1247 - smooth_l1: 1.0641
# Epoch 1: loss improved from 0.14128 to 0.13954, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 349/605 [================>.............] - ETA: 2:49 - loss: 0.1386 - confidence_loss: 0.0071 - class_loss: 0.1248 - smooth_l1: 1.0640
# Epoch 1: loss improved from 0.13954 to 0.13852, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 399/605 [==================>...........] - ETA: 2:16 - loss: 0.1371 - confidence_loss: 0.0070 - class_loss: 0.1250 - smooth_l1: 1.0652
# Epoch 1: loss improved from 0.13852 to 0.13734, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 449/605 [=====================>........] - ETA: 1:43 - loss: 0.1350 - confidence_loss: 0.0070 - class_loss: 0.1250 - smooth_l1: 1.0659
# Epoch 1: loss improved from 0.13734 to 0.13482, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 499/605 [=======================>......] - ETA: 1:10 - loss: 0.1359 - confidence_loss: 0.0069 - class_loss: 0.1251 - smooth_l1: 1.0668
# Epoch 1: loss did not improve from 0.13482
# 549/605 [==========================>...] - ETA: 37s - loss: 0.1348 - confidence_loss: 0.0069 - class_loss: 0.1252 - smooth_l1: 1.0678
# Epoch 1: loss did not improve from 0.13482
# 599/605 [============================>.] - ETA: 3s - loss: 0.1335 - confidence_loss: 0.0069 - class_loss: 0.1251 - smooth_l1: 1.0677
# Epoch 1: loss improved from 0.13482 to 0.13340, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 605/605 [==============================] - 480s 792ms/step - loss: 0.1329 - confidence_loss: 0.0069 - class_loss: 0.1251 - smooth_l1: 1.0679 - val_loss: 0.6552 - val_confidence_loss: 0.0122 - val_class_loss: 0.1256 - val_smooth_l1: 1.0644
# Epoch 2/10
#  44/605 [=>............................] - ETA: 6:06 - loss: 0.1252 - confidence_loss: 0.0066 - class_loss: 0.1245 - smooth_l1: 1.0583
# Epoch 2: loss improved from 0.13340 to 0.12529, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
#  94/605 [===>..........................] - ETA: 5:39 - loss: 0.1206 - confidence_loss: 0.0065 - class_loss: 0.1255 - smooth_l1: 1.0515
# Epoch 2: loss improved from 0.12529 to 0.12138, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 144/605 [======>.......................] - ETA: 5:07 - loss: 0.1207 - confidence_loss: 0.0065 - class_loss: 0.1253 - smooth_l1: 1.0490
# Epoch 2: loss improved from 0.12138 to 0.12087, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 194/605 [========>.....................] - ETA: 4:34 - loss: 0.1153 - confidence_loss: 0.0064 - class_loss: 0.1253 - smooth_l1: 1.0497
# Epoch 2: loss improved from 0.12087 to 0.11543, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 244/605 [===========>..................] - ETA: 4:01 - loss: 0.1143 - confidence_loss: 0.0064 - class_loss: 0.1255 - smooth_l1: 1.0482
# Epoch 2: loss improved from 0.11543 to 0.11451, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 294/605 [=============>................] - ETA: 3:27 - loss: 0.1144 - confidence_loss: 0.0064 - class_loss: 0.1255 - smooth_l1: 1.0472
# Epoch 2: loss did not improve from 0.11451
# 344/605 [================>.............] - ETA: 2:53 - loss: 0.1132 - confidence_loss: 0.0063 - class_loss: 0.1254 - smooth_l1: 1.0477
# Epoch 2: loss improved from 0.11451 to 0.11328, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 394/605 [==================>...........] - ETA: 2:20 - loss: 0.1134 - confidence_loss: 0.0062 - class_loss: 0.1254 - smooth_l1: 1.0474
# Epoch 2: loss did not improve from 0.11328
# 444/605 [=====================>........] - ETA: 1:47 - loss: 0.1140 - confidence_loss: 0.0062 - class_loss: 0.1253 - smooth_l1: 1.0472
# Epoch 2: loss did not improve from 0.11328
# 494/605 [=======================>......] - ETA: 1:13 - loss: 0.1137 - confidence_loss: 0.0062 - class_loss: 0.1253 - smooth_l1: 1.0476
# Epoch 2: loss did not improve from 0.11328
# 544/605 [=========================>....] - ETA: 40s - loss: 0.1142 - confidence_loss: 0.0062 - class_loss: 0.1253 - smooth_l1: 1.0473
# Epoch 2: loss did not improve from 0.11328
# 594/605 [============================>.] - ETA: 7s - loss: 0.1128 - confidence_loss: 0.0061 - class_loss: 0.1251 - smooth_l1: 1.0462
# Epoch 2: loss improved from 0.11328 to 0.11293, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 605/605 [==============================] - 478s 790ms/step - loss: 0.1129 - confidence_loss: 0.0061 - class_loss: 0.1251 - smooth_l1: 1.0459 - val_loss: 0.6698 - val_confidence_loss: 0.0119 - val_class_loss: 0.1248 - val_smooth_l1: 1.0582
# Epoch 3/10
#  39/605 [>.............................] - ETA: 6:10 - loss: 0.0938 - confidence_loss: 0.0058 - class_loss: 0.1239 - smooth_l1: 1.0343
# Epoch 3: loss improved from 0.11293 to 0.09331, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
#  89/605 [===>..........................] - ETA: 5:42 - loss: 0.0941 - confidence_loss: 0.0057 - class_loss: 0.1240 - smooth_l1: 1.0289
# Epoch 3: loss did not improve from 0.09331
# 139/605 [=====>........................] - ETA: 5:07 - loss: 0.1017 - confidence_loss: 0.0057 - class_loss: 0.1238 - smooth_l1: 1.0293
# Epoch 3: loss did not improve from 0.09331
# 189/605 [========>.....................] - ETA: 4:34 - loss: 0.1017 - confidence_loss: 0.0057 - class_loss: 0.1236 - smooth_l1: 1.0262
# Epoch 3: loss did not improve from 0.09331
# 239/605 [==========>...................] - ETA: 4:01 - loss: 0.1050 - confidence_loss: 0.0057 - class_loss: 0.1239 - smooth_l1: 1.0276
# Epoch 3: loss did not improve from 0.09331
# 289/605 [=============>................] - ETA: 3:27 - loss: 0.1041 - confidence_loss: 0.0056 - class_loss: 0.1240 - smooth_l1: 1.0277
# Epoch 3: loss did not improve from 0.09331
# 339/605 [===============>..............] - ETA: 2:54 - loss: 0.1033 - confidence_loss: 0.0056 - class_loss: 0.1241 - smooth_l1: 1.0285
# Epoch 3: loss did not improve from 0.09331
# 389/605 [==================>...........] - ETA: 2:21 - loss: 0.1044 - confidence_loss: 0.0056 - class_loss: 0.1242 - smooth_l1: 1.0274
# Epoch 3: loss did not improve from 0.09331
# 439/605 [====================>.........] - ETA: 1:49 - loss: 0.1045 - confidence_loss: 0.0056 - class_loss: 0.1241 - smooth_l1: 1.0253
# Epoch 3: loss did not improve from 0.09331
# 489/605 [=======================>......] - ETA: 1:16 - loss: 0.1041 - confidence_loss: 0.0056 - class_loss: 0.1241 - smooth_l1: 1.0255
# Epoch 3: loss did not improve from 0.09331
# 539/605 [=========================>....] - ETA: 43s - loss: 0.1031 - confidence_loss: 0.0055 - class_loss: 0.1241 - smooth_l1: 1.0244
# Epoch 3: loss did not improve from 0.09331
# 589/605 [============================>.] - ETA: 10s - loss: 0.1042 - confidence_loss: 0.0055 - class_loss: 0.1242 - smooth_l1: 1.0238
# Epoch 3: loss did not improve from 0.09331
# 605/605 [==============================] - 474s 783ms/step - loss: 0.1037 - confidence_loss: 0.0055 - class_loss: 0.1242 - smooth_l1: 1.0234 - val_loss: 0.6729 - val_confidence_loss: 0.0117 - val_class_loss: 0.1230 - val_smooth_l1: 0.9899
# Epoch 4/10
#  34/605 [>.............................] - ETA: 6:13 - loss: 0.1002 - confidence_loss: 0.0053 - class_loss: 0.1249 - smooth_l1: 1.0079
# Epoch 4: loss did not improve from 0.09331
#  84/605 [===>..........................] - ETA: 5:41 - loss: 0.0987 - confidence_loss: 0.0053 - class_loss: 0.1237 - smooth_l1: 1.0130
# Epoch 4: loss did not improve from 0.09331
# 134/605 [=====>........................] - ETA: 5:08 - loss: 0.1005 - confidence_loss: 0.0053 - class_loss: 0.1236 - smooth_l1: 1.0102
# Epoch 4: loss did not improve from 0.09331
# 184/605 [========>.....................] - ETA: 4:35 - loss: 0.0996 - confidence_loss: 0.0053 - class_loss: 0.1236 - smooth_l1: 1.0067
# Epoch 4: loss did not improve from 0.09331
# 234/605 [==========>...................] - ETA: 4:03 - loss: 0.0974 - confidence_loss: 0.0052 - class_loss: 0.1235 - smooth_l1: 1.0051
# Epoch 4: loss did not improve from 0.09331
# 284/605 [=============>................] - ETA: 3:30 - loss: 0.0970 - confidence_loss: 0.0052 - class_loss: 0.1234 - smooth_l1: 1.0031
# Epoch 4: loss did not improve from 0.09331
# 334/605 [===============>..............] - ETA: 2:57 - loss: 0.0980 - confidence_loss: 0.0052 - class_loss: 0.1230 - smooth_l1: 1.0020
# Epoch 4: loss did not improve from 0.09331
# 384/605 [==================>...........] - ETA: 2:24 - loss: 0.0970 - confidence_loss: 0.0052 - class_loss: 0.1229 - smooth_l1: 1.0011
# Epoch 4: loss did not improve from 0.09331
# 434/605 [====================>.........] - ETA: 1:52 - loss: 0.0962 - confidence_loss: 0.0051 - class_loss: 0.1227 - smooth_l1: 1.0002
# Epoch 4: loss did not improve from 0.09331
# 484/605 [=======================>......] - ETA: 1:19 - loss: 0.0952 - confidence_loss: 0.0051 - class_loss: 0.1225 - smooth_l1: 0.9995
# Epoch 4: loss did not improve from 0.09331
# 534/605 [=========================>....] - ETA: 46s - loss: 0.0943 - confidence_loss: 0.0051 - class_loss: 0.1223 - smooth_l1: 0.9987
# Epoch 4: loss did not improve from 0.09331
# 584/605 [===========================>..] - ETA: 13s - loss: 0.0956 - confidence_loss: 0.0050 - class_loss: 0.1222 - smooth_l1: 0.9970
# Epoch 4: loss did not improve from 0.09331
# 605/605 [==============================] - 473s 781ms/step - loss: 0.0951 - confidence_loss: 0.0050 - class_loss: 0.1221 - smooth_l1: 0.9966 - val_loss: 0.6940 - val_confidence_loss: 0.0113 - val_class_loss: 0.1198 - val_smooth_l1: 0.9581
# Epoch 5/10
#  29/605 [>.............................] - ETA: 6:18 - loss: 0.1035 - confidence_loss: 0.0049 - class_loss: 0.1203 - smooth_l1: 0.9978
# Epoch 5: loss did not improve from 0.09331
#  79/605 [==>...........................] - ETA: 5:45 - loss: 0.0895 - confidence_loss: 0.0047 - class_loss: 0.1199 - smooth_l1: 0.9889
# Epoch 5: loss improved from 0.09331 to 0.08884, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 129/605 [=====>........................] - ETA: 5:14 - loss: 0.0950 - confidence_loss: 0.0048 - class_loss: 0.1198 - smooth_l1: 0.9833
# Epoch 5: loss did not improve from 0.08884
# 179/605 [=======>......................] - ETA: 4:40 - loss: 0.0946 - confidence_loss: 0.0048 - class_loss: 0.1199 - smooth_l1: 0.9834
# Epoch 5: loss did not improve from 0.08884
# 229/605 [==========>...................] - ETA: 4:07 - loss: 0.0932 - confidence_loss: 0.0048 - class_loss: 0.1197 - smooth_l1: 0.9846
# Epoch 5: loss did not improve from 0.08884
# 279/605 [============>.................] - ETA: 3:34 - loss: 0.0936 - confidence_loss: 0.0047 - class_loss: 0.1196 - smooth_l1: 0.9853
# Epoch 5: loss did not improve from 0.08884
# 329/605 [===============>..............] - ETA: 3:01 - loss: 0.0925 - confidence_loss: 0.0047 - class_loss: 0.1193 - smooth_l1: 0.9853
# Epoch 5: loss did not improve from 0.08884
# 379/605 [=================>............] - ETA: 2:28 - loss: 0.0918 - confidence_loss: 0.0047 - class_loss: 0.1191 - smooth_l1: 0.9857
# Epoch 5: loss did not improve from 0.08884
# 429/605 [====================>.........] - ETA: 1:55 - loss: 0.0915 - confidence_loss: 0.0047 - class_loss: 0.1191 - smooth_l1: 0.9853
# Epoch 5: loss did not improve from 0.08884
# 479/605 [======================>.......] - ETA: 1:22 - loss: 0.0905 - confidence_loss: 0.0046 - class_loss: 0.1190 - smooth_l1: 0.9844
# Epoch 5: loss did not improve from 0.08884
# 529/605 [=========================>....] - ETA: 49s - loss: 0.0899 - confidence_loss: 0.0046 - class_loss: 0.1188 - smooth_l1: 0.9839
# Epoch 5: loss did not improve from 0.08884
# 579/605 [===========================>..] - ETA: 17s - loss: 0.0894 - confidence_loss: 0.0046 - class_loss: 0.1188 - smooth_l1: 0.9832
# Epoch 5: loss did not improve from 0.08884
# 605/605 [==============================] - 473s 782ms/step - loss: 0.0897 - confidence_loss: 0.0046 - class_loss: 0.1188 - smooth_l1: 0.9830 - val_loss: 0.6929 - val_confidence_loss: 0.0114 - val_class_loss: 0.1182 - val_smooth_l1: 0.9928
# Epoch 6/10
#  24/605 [>.............................] - ETA: 6:20 - loss: 0.0925 - confidence_loss: 0.0045 - class_loss: 0.1179 - smooth_l1: 0.9770
# Epoch 6: loss did not improve from 0.08884
#  74/605 [==>...........................] - ETA: 5:47 - loss: 0.0858 - confidence_loss: 0.0044 - class_loss: 0.1190 - smooth_l1: 0.9710
# Epoch 6: loss improved from 0.08884 to 0.08549, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 124/605 [=====>........................] - ETA: 5:18 - loss: 0.0845 - confidence_loss: 0.0043 - class_loss: 0.1184 - smooth_l1: 0.9717
# Epoch 6: loss improved from 0.08549 to 0.08435, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 174/605 [=======>......................] - ETA: 4:46 - loss: 0.0840 - confidence_loss: 0.0043 - class_loss: 0.1178 - smooth_l1: 0.9723
# Epoch 6: loss improved from 0.08435 to 0.08376, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
# 224/605 [==========>...................] - ETA: 4:13 - loss: 0.0844 - confidence_loss: 0.0043 - class_loss: 0.1172 - smooth_l1: 0.9730
# Epoch 6: loss did not improve from 0.08376
# 274/605 [============>.................] - ETA: 3:39 - loss: 0.0856 - confidence_loss: 0.0043 - class_loss: 0.1171 - smooth_l1: 0.9720
# Epoch 6: loss did not improve from 0.08376
# 324/605 [===============>..............] - ETA: 3:06 - loss: 0.0847 - confidence_loss: 0.0043 - class_loss: 0.1169 - smooth_l1: 0.9707
# Epoch 6: loss did not improve from 0.08376
# 374/605 [=================>............] - ETA: 2:32 - loss: 0.0844 - confidence_loss: 0.0042 - class_loss: 0.1170 - smooth_l1: 0.9689
# Epoch 6: loss did not improve from 0.08376
# 424/605 [====================>.........] - ETA: 1:59 - loss: 0.0845 - confidence_loss: 0.0042 - class_loss: 0.1169 - smooth_l1: 0.9687
# Epoch 6: loss did not improve from 0.08376
# 474/605 [======================>.......] - ETA: 1:26 - loss: 0.0839 - confidence_loss: 0.0042 - class_loss: 0.1167 - smooth_l1: 0.9685
# Epoch 6: loss did not improve from 0.08376
# 524/605 [========================>.....] - ETA: 53s - loss: 0.0843 - confidence_loss: 0.0042 - class_loss: 0.1166 - smooth_l1: 0.9678
# Epoch 6: loss did not improve from 0.08376
# 574/605 [===========================>..] - ETA: 20s - loss: 0.0840 - confidence_loss: 0.0042 - class_loss: 0.1163 - smooth_l1: 0.9665
# Epoch 6: loss did not improve from 0.08376
# 605/605 [==============================] - 475s 785ms/step - loss: 0.0841 - confidence_loss: 0.0042 - class_loss: 0.1163 - smooth_l1: 0.9658 - val_loss: 0.7206 - val_confidence_loss: 0.0112 - val_class_loss: 0.1153 - val_smooth_l1: 0.9503
# Epoch 7/10
#  19/605 [..............................] - ETA: 6:21 - loss: 0.0614 - confidence_loss: 0.0037 - class_loss: 0.1152 - smooth_l1: 0.9557
# Epoch 7: loss improved from 0.08376 to 0.06095, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
#  69/605 [==>...........................] - ETA: 5:56 - loss: 0.0769 - confidence_loss: 0.0038 - class_loss: 0.1148 - smooth_l1: 0.9554
# Epoch 7: loss did not improve from 0.06095
# 119/605 [====>.........................] - ETA: 5:21 - loss: 0.0772 - confidence_loss: 0.0038 - class_loss: 0.1151 - smooth_l1: 0.9520
# Epoch 7: loss did not improve from 0.06095
# 169/605 [=======>......................] - ETA: 4:47 - loss: 0.0776 - confidence_loss: 0.0039 - class_loss: 0.1151 - smooth_l1: 0.9553
# Epoch 7: loss did not improve from 0.06095
# 219/605 [=========>....................] - ETA: 4:13 - loss: 0.0778 - confidence_loss: 0.0039 - class_loss: 0.1148 - smooth_l1: 0.9543
# Epoch 7: loss did not improve from 0.06095
# 269/605 [============>.................] - ETA: 3:40 - loss: 0.0783 - confidence_loss: 0.0039 - class_loss: 0.1147 - smooth_l1: 0.9530
# Epoch 7: loss did not improve from 0.06095
# 319/605 [==============>...............] - ETA: 3:07 - loss: 0.0783 - confidence_loss: 0.0039 - class_loss: 0.1146 - smooth_l1: 0.9515
# Epoch 7: loss did not improve from 0.06095
# 369/605 [=================>............] - ETA: 2:34 - loss: 0.0789 - confidence_loss: 0.0038 - class_loss: 0.1146 - smooth_l1: 0.9511
# Epoch 7: loss did not improve from 0.06095
# 419/605 [===================>..........] - ETA: 2:02 - loss: 0.0791 - confidence_loss: 0.0038 - class_loss: 0.1143 - smooth_l1: 0.9506
# Epoch 7: loss did not improve from 0.06095
# 469/605 [======================>.......] - ETA: 1:29 - loss: 0.0783 - confidence_loss: 0.0038 - class_loss: 0.1142 - smooth_l1: 0.9514
# Epoch 7: loss did not improve from 0.06095
# 519/605 [========================>.....] - ETA: 56s - loss: 0.0791 - confidence_loss: 0.0038 - class_loss: 0.1141 - smooth_l1: 0.9507
# Epoch 7: loss did not improve from 0.06095
# 569/605 [===========================>..] - ETA: 23s - loss: 0.0784 - confidence_loss: 0.0038 - class_loss: 0.1140 - smooth_l1: 0.9497
# Epoch 7: loss did not improve from 0.06095
# 605/605 [==============================] - 473s 782ms/step - loss: 0.0791 - confidence_loss: 0.0038 - class_loss: 0.1140 - smooth_l1: 0.9495 - val_loss: 0.7292 - val_confidence_loss: 0.0113 - val_class_loss: 0.1137 - val_smooth_l1: 0.9269
# Epoch 8/10
#  14/605 [..............................] - ETA: 6:24 - loss: 0.0754 - confidence_loss: 0.0035 - class_loss: 0.1139 - smooth_l1: 0.9325
# Epoch 8: loss did not improve from 0.06095
#  64/605 [==>...........................] - ETA: 5:53 - loss: 0.0768 - confidence_loss: 0.0036 - class_loss: 0.1134 - smooth_l1: 0.9348
# Epoch 8: loss did not improve from 0.06095
# 114/605 [====>.........................] - ETA: 5:21 - loss: 0.0802 - confidence_loss: 0.0037 - class_loss: 0.1134 - smooth_l1: 0.9367
# Epoch 8: loss did not improve from 0.06095
# 164/605 [=======>......................] - ETA: 4:48 - loss: 0.0782 - confidence_loss: 0.0037 - class_loss: 0.1128 - smooth_l1: 0.9369
# Epoch 8: loss did not improve from 0.06095
# 214/605 [=========>....................] - ETA: 4:16 - loss: 0.0781 - confidence_loss: 0.0036 - class_loss: 0.1128 - smooth_l1: 0.9336
# Epoch 8: loss did not improve from 0.06095
# 264/605 [============>.................] - ETA: 3:43 - loss: 0.0774 - confidence_loss: 0.0036 - class_loss: 0.1127 - smooth_l1: 0.9339
# Epoch 8: loss did not improve from 0.06095
# 314/605 [==============>...............] - ETA: 3:10 - loss: 0.0763 - confidence_loss: 0.0036 - class_loss: 0.1125 - smooth_l1: 0.9349
# Epoch 8: loss did not improve from 0.06095
# 364/605 [=================>............] - ETA: 2:37 - loss: 0.0754 - confidence_loss: 0.0035 - class_loss: 0.1124 - smooth_l1: 0.9345
# Epoch 8: loss did not improve from 0.06095
# 414/605 [===================>..........] - ETA: 2:05 - loss: 0.0748 - confidence_loss: 0.0035 - class_loss: 0.1123 - smooth_l1: 0.9325
# Epoch 8: loss did not improve from 0.06095
# 464/605 [======================>.......] - ETA: 1:32 - loss: 0.0751 - confidence_loss: 0.0035 - class_loss: 0.1121 - smooth_l1: 0.9317
# Epoch 8: loss did not improve from 0.06095
# 514/605 [========================>.....] - ETA: 59s - loss: 0.0759 - confidence_loss: 0.0035 - class_loss: 0.1121 - smooth_l1: 0.9299
# Epoch 8: loss did not improve from 0.06095
# 564/605 [==========================>...] - ETA: 26s - loss: 0.0755 - confidence_loss: 0.0035 - class_loss: 0.1120 - smooth_l1: 0.9289
# Epoch 8: loss did not improve from 0.06095
# 605/605 [==============================] - 473s 781ms/step - loss: 0.0760 - confidence_loss: 0.0035 - class_loss: 0.1120 - smooth_l1: 0.9282 - val_loss: 0.7380 - val_confidence_loss: 0.0110 - val_class_loss: 0.1134 - val_smooth_l1: 0.9030
# Epoch 9/10
#   9/605 [..............................] - ETA: 6:31 - loss: 0.0806 - confidence_loss: 0.0035 - class_loss: 0.1116 - smooth_l1: 0.9277
# Epoch 9: loss did not improve from 0.06095
#  59/605 [=>............................] - ETA: 5:58 - loss: 0.0720 - confidence_loss: 0.0033 - class_loss: 0.1121 - smooth_l1: 0.9150
# Epoch 9: loss did not improve from 0.06095
# 109/605 [====>.........................] - ETA: 5:25 - loss: 0.0731 - confidence_loss: 0.0033 - class_loss: 0.1121 - smooth_l1: 0.9136
# Epoch 9: loss did not improve from 0.06095
# 159/605 [======>.......................] - ETA: 4:52 - loss: 0.0729 - confidence_loss: 0.0034 - class_loss: 0.1117 - smooth_l1: 0.9132
# Epoch 9: loss did not improve from 0.06095
# 209/605 [=========>....................] - ETA: 4:19 - loss: 0.0716 - confidence_loss: 0.0033 - class_loss: 0.1114 - smooth_l1: 0.9117
# Epoch 9: loss did not improve from 0.06095
# 259/605 [===========>..................] - ETA: 3:46 - loss: 0.0719 - confidence_loss: 0.0034 - class_loss: 0.1113 - smooth_l1: 0.9107
# Epoch 9: loss did not improve from 0.06095
# 309/605 [==============>...............] - ETA: 3:14 - loss: 0.0732 - confidence_loss: 0.0033 - class_loss: 0.1114 - smooth_l1: 0.9106
# Epoch 9: loss did not improve from 0.06095
# 359/605 [================>.............] - ETA: 2:41 - loss: 0.0732 - confidence_loss: 0.0033 - class_loss: 0.1112 - smooth_l1: 0.9101
# Epoch 9: loss did not improve from 0.06095
# 409/605 [===================>..........] - ETA: 2:08 - loss: 0.0729 - confidence_loss: 0.0033 - class_loss: 0.1108 - smooth_l1: 0.9093
# Epoch 9: loss did not improve from 0.06095
# 459/605 [=====================>........] - ETA: 1:35 - loss: 0.0725 - confidence_loss: 0.0033 - class_loss: 0.1106 - smooth_l1: 0.9083
# Epoch 9: loss did not improve from 0.06095
# 509/605 [========================>.....] - ETA: 1:02 - loss: 0.0727 - confidence_loss: 0.0033 - class_loss: 0.1103 - smooth_l1: 0.9067
# Epoch 9: loss did not improve from 0.06095
# 559/605 [==========================>...] - ETA: 30s - loss: 0.0733 - confidence_loss: 0.0033 - class_loss: 0.1103 - smooth_l1: 0.9055
# Epoch 9: loss did not improve from 0.06095
# 605/605 [==============================] - 472s 781ms/step - loss: 0.0730 - confidence_loss: 0.0033 - class_loss: 0.1102 - smooth_l1: 0.9050 - val_loss: 0.7589 - val_confidence_loss: 0.0107 - val_class_loss: 0.1083 - val_smooth_l1: 0.8897
# Epoch 10/10
#   4/605 [..............................] - ETA: 6:41 - loss: 0.0496 - confidence_loss: 0.0028 - class_loss: 0.1104 - smooth_l1: 0.8943
# Epoch 10: loss improved from 0.06095 to 0.04720, saving model to /content/drive/MyDrive/fish/fishdetector_wh_val.hdf5
#  54/605 [=>............................] - ETA: 6:10 - loss: 0.0653 - confidence_loss: 0.0032 - class_loss: 0.1084 - smooth_l1: 0.8917
# Epoch 10: loss did not improve from 0.04720
# 104/605 [====>.........................] - ETA: 5:33 - loss: 0.0689 - confidence_loss: 0.0032 - class_loss: 0.1086 - smooth_l1: 0.8912
# Epoch 10: loss did not improve from 0.04720
# 154/605 [======>.......................] - ETA: 4:58 - loss: 0.0693 - confidence_loss: 0.0032 - class_loss: 0.1080 - smooth_l1: 0.8899
# Epoch 10: loss did not improve from 0.04720
# 204/605 [=========>....................] - ETA: 4:24 - loss: 0.0679 - confidence_loss: 0.0031 - class_loss: 0.1079 - smooth_l1: 0.8920
# Epoch 10: loss did not improve from 0.04720
# 254/605 [===========>..................] - ETA: 3:51 - loss: 0.0670 - confidence_loss: 0.0031 - class_loss: 0.1078 - smooth_l1: 0.8918
# Epoch 10: loss did not improve from 0.04720
# 304/605 [==============>...............] - ETA: 3:18 - loss: 0.0680 - confidence_loss: 0.0031 - class_loss: 0.1077 - smooth_l1: 0.8914
# Epoch 10: loss did not improve from 0.04720
# 354/605 [================>.............] - ETA: 2:45 - loss: 0.0685 - confidence_loss: 0.0031 - class_loss: 0.1076 - smooth_l1: 0.8905
# Epoch 10: loss did not improve from 0.04720
# 404/605 [===================>..........] - ETA: 2:12 - loss: 0.0676 - confidence_loss: 0.0031 - class_loss: 0.1074 - smooth_l1: 0.8889
# Epoch 10: loss did not improve from 0.04720
# 454/605 [=====================>........] - ETA: 1:39 - loss: 0.0686 - confidence_loss: 0.0031 - class_loss: 0.1074 - smooth_l1: 0.8881
# Epoch 10: loss did not improve from 0.04720
# 504/605 [=======================>......] - ETA: 1:06 - loss: 0.0694 - confidence_loss: 0.0031 - class_loss: 0.1075 - smooth_l1: 0.8866
# Epoch 10: loss did not improve from 0.04720
# 554/605 [==========================>...] - ETA: 33s - loss: 0.0693 - confidence_loss: 0.0031 - class_loss: 0.1075 - smooth_l1: 0.8859
# Epoch 10: loss did not improve from 0.04720
# 604/605 [============================>.] - ETA: 0s - loss: 0.0694 - confidence_loss: 0.0031 - class_loss: 0.1075 - smooth_l1: 0.8856
# Epoch 10: loss did not improve from 0.04720
# 605/605 [==============================] - 474s 783ms/step - loss: 0.0694 - confidence_loss: 0.0031 - class_loss: 0.1075 - smooth_l1: 0.8856 - val_loss: 0.7771 - val_confidence_loss: 0.0113 - val_class_loss: 0.1072 - val_smooth_l1: 0.8702

# %% [markdown]
# ## Результат работы детектора

# %%
model.load_weights('/content/drive/MyDrive/fish/fishdetector_wh_val.hdf5')
#model = tf.keras.models.load_model('/content/drive/MyDrive/fish/fishdetector_wh.hdf5')

# %% [markdown]
# Продемонстрируем работу модели на тренировочных данных (зеленым обозначена исходная разметка и класс; красным - предсказанный моделью класс и область размещения):

# %%
annotation = boxes['other'][3]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.1)

decoded = non_max_suppression(decoded,
                              max_output_size=2,
                              iou_threshold=0.5)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));

# %% [markdown]
# На данной фотографии две рыбы и две области, на деле модель более-менее справляется только с первой областью, погрешность для второй и следующих высокая, поэтому ограничимся только ею.

# %% [markdown]
# Ещё несколько примеров на тренировочных данных для разных классов:

# %%
# {'filename': filename['filename']}
test_images = [boxes['alb'][1], boxes['alb'][3], boxes['yft'][1],
               boxes['yft'][7], boxes['other'][0], boxes['other'][1],
               boxes['bet'][1], boxes['bet'][6], boxes['shark'][3],
               boxes['shark'][6], boxes['dol'][0], boxes['dol'][1],
               boxes['lag'][0], boxes['lag'][8]
]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename['filename'])

    pred = model.predict(np.array([sample_img,]))
    decoded = decode_prediction(pred[0], conf_thr=0.003)
    decoded = non_max_suppression(decoded,
                                  max_output_size=1,
                                  iou_threshold=0.1)
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes(filename, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание модели {}'.format(filename['filename'].split('/')[-1]));
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Визуализируем предсказание на тесте

# %%
with zipfile.ZipFile("/content/drive/MyDrive/fish/test_stg1.zip","r") as z:
    z.extractall(".")
import py7zr
with py7zr.SevenZipFile("/content/drive/MyDrive/fish/test_stg2.7z", mode='r') as z:
    z.extractall()

# %%
test_images = glob('test_stg1/*.jpg')[550:570]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)

    pred = model.predict(np.array([sample_img,]))
    decoded = decode_prediction(pred[0], conf_thr=0.002)
    decoded = non_max_suppression(decoded,
                                  max_output_size=1,
                                  iou_threshold=0.1)
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename.split('/')[-1]));
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Готовим данные для сабмита

# %%
# TODO: предскажите класс рыбы для фотографии из тестовой выборки
#
# Подготовьте файл с предсказаниями вероятностей для каждой фотографии:
# image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT
# img_00001.jpg,1,0,0,0,0,...,0
# img_00002.jpg,0.3,0.1,0.6,0,...,0

# %%
fish_classes
# Out:
# array(['alb', 'yft', 'nof', 'other', 'bet', 'shark', 'dol', 'lag'],
#       dtype=object)

# %%
import re
p = re.compile(r'_(\d+)')
CONF_THR = 0.003

def make_predictions() -> pd.DataFrame:
    df_submit = []

    images_list =glob('test_stg1/*.jpg')
    images_list = sorted(images_list, key = lambda s: int(p.search(s).group(1)))

    for file in tqdm(images_list):
        _, sample_img = load_img(file)
        
        pred = model.predict(np.array([sample_img,]))[0]
        decoded = decode_prediction(pred, conf_thr=CONF_THR)
        decoded = non_max_suppression(decoded,
                              max_output_size=1,
                              iou_threshold=0.5)
        
        row_predict = {}
        
        row_predict['image'] = re.search("img_\d+\.jpg", file)[0]
        #row_predict['conf'] = decoded[0]['conf']
        
        decoded = decoded[0]['labels']
        
        row_predict['ALB'] = decoded[0]
        row_predict['BET'] = decoded[4]
        row_predict['DOL'] = decoded[6]
        row_predict['LAG'] = decoded[7]
        row_predict['NoF'] = decoded[2] # фиксированная вероятность для класса 'No Fishes' из файла sample_submission
        row_predict['OTHER'] = decoded[3]
        row_predict['SHARK'] = decoded[5]
        row_predict['YFT'] = decoded[1]     

        df_submit.append(row_predict)

    images_list = glob('test_stg2/*.jpg')
    images_list = sorted(images_list, key = lambda s: int(p.search(s).group(1)))

    for file in tqdm(images_list):
        _, sample_img = load_img(file)
        
        pred = model.predict(np.array([sample_img,]))[0]
        decoded = decode_prediction(pred, conf_thr=CONF_THR)
        decoded = non_max_suppression(decoded,
                              max_output_size=1,
                              iou_threshold=0.5)
        
        row_predict = {}
        
        row_predict['image'] = 'test_stg2/' + re.search("image_\d+\.jpg", file)[0]
        #row_predict['conf'] = decoded[0]['conf']
        
        decoded = decoded[0]['labels']
        
        row_predict['ALB'] = decoded[0]
        row_predict['BET'] = decoded[4]
        row_predict['DOL'] = decoded[6]
        row_predict['LAG'] = decoded[7]
        row_predict['NoF'] = decoded[2] # фиксированная вероятность для класса 'No Fishes' из файла sample_submission
        row_predict['OTHER'] = decoded[3]
        row_predict['SHARK'] = decoded[5]
        row_predict['YFT'] = decoded[1]    
       
        df_submit.append(row_predict)

    return pd.DataFrame.from_dict(df_submit)

# %%
df_submit = make_predictions()
df_submit.to_csv("/content/drive/MyDrive/fish/submit_hw3_val.csv", index=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/12153 [00:00<?, ?it/s]

# %% [markdown]
# ## Результат на kaggle

# %% [markdown]
# Ранее я загружал решение, рассчитанное на том же количестве эпох, но без валидации и разметки категории NoF (нет рыбы), можно видеть как разметка NoF улучшила результат.

# %% [markdown]
# ![submit_hw3.jpg](data:image/jpeg;base64,...)
