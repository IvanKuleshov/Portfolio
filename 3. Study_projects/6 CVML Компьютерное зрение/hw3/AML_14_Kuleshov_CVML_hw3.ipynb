# %% [markdown]
# **Кулешов Иван AML-14**

# %% [markdown]
# # Домашнее задание «Задачи детекции и сегментации»

# %% [markdown]
# В данном задании вам предстоит помочь The Nature Conservancy в борьбе с рыбаками-браконьерами. Необходимо по снимкам с камеры на рыболовецком судне классифицировать улов.

# %% [markdown]
# # The Nature Conservancy Fisheries Monitoring

# %% [markdown]
# Домашнее задание к занятию «Задачи детекции и сегментации».
#
# В данном задании вам предстоит помочь The Nature Conservancy в борьбе с рыбаками-браконьерами.
# Необходимо по снимкам с камеры на рыболовецком судне классифицировать улов. За основу решения предлагается взять модель детектора:
# [github.com...tion.ipynb](https://github.com/a4tunado/lectures/blob/master/007/007-detection.ipynb). Решение необходимо прислать в виде ссылки на ipython-ноутбук с указанием значения метрики на Leaderboard.

# %% [markdown]
# https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tqdm.notebook import tqdm
import zipfile
from scipy.special import softmax
from matplotlib import pyplot as plt

# !pip install py7zr

# %% [markdown]
# # Загружаем разметку

# %% [markdown]
# ⛏ Всю разработку будем вести в google Colab - подключаем Гугл.Диск и распаковываем в рабочую область исходные данные

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with zipfile.ZipFile("/content/drive/MyDrive/fish/train.zip","r") as z:
    z.extractall(".")

# %% [markdown]
# ---

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = 'train'
BOXES_PATH = '/content/drive/MyDrive/fish/boxes/'

def load_annotations():
    boxes = dict()
    for path in tqdm(glob(BOXES_PATH + '*.json')):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            for annotation in json.load(src):
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(
                    TRAIN_PREFIX, label.upper(), basename)
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
                    rect['class'] = label
                if os.path.isfile(annotation['filename']):
                    boxes.setdefault(label, []).append(annotation)
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for i, rect in enumerate(rectangles):
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=10)
            img = cv2.putText(img.copy(), annotation['annotations'][i]['class'], tuple(np.array(pt1)+[0,-7]), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 4 )
        return img
    
    def __draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for i, rect in enumerate(rectangles):
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=3)
            img = cv2.putText(img.copy(), counts['class'][int(rect['label'])] + ': ' + str(rect['label']), tuple(np.array(pt1)+[0,-7]), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 4 )
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation.get('annotations', []), scale_x, scale_y)
    
    if rectangles is not None:
        img = __draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %% [markdown]
# ### Визуализируем разметку

# %%
boxes = load_annotations()  # загружаем разметку детекций
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
counts = pd.DataFrame(
    [(k, len(v)) for k, v in boxes.items()],
    columns=['class', 'count']).sort_values(by='count', ascending=False).reset_index()

fish_classes = counts['class'].values
print(fish_classes)
counts
# Out:
# ['alb' 'yft' 'other' 'bet' 'shark' 'dol' 'lag']
#    index  class  count
# 0      5    alb   1719
# 1      2    yft    734
# 2      6  other    299
# 3      0    bet    200
# 4      4  shark    176
# 5      3    dol    117
# 6      1    lag     67

# %%
# Легенда классификации рыб будет выглядеть так:
# class 0: alb - Albacore tuna 
# class 1: yft - Yellowfin tuna
# class 2: oth - Other Fishes (на фото другие рыбы, не относящиеся ни к одному другому классу)
# class 3: bet - Bigeye tuna
# class 4: shark - Sharks
# class 5: dol - Dolphinfish (Mahi Mahi)
# class 6: lag - Opah, Moonfish (Lamprus Guttatus)

# Остальные классы - без разметки:
# nof - No Fishes (на фото нет никаких рыб)

# %% [markdown]
# ⛏ Выведем пример разметки для разных классов, включая класс OTHER (раз уж выданный для задания ноутбук содержит почти всё, надо хоть что-то сделать, например, разметку OTHER)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(8, 12), dpi=120)
boxes_ = [boxes['other'][3],boxes['other'][4],boxes['alb'][0],boxes['bet'][0],boxes['dol'][0],boxes['lag'][0],
         boxes['shark'][0], boxes['yft'][0]]

for i, box in enumerate(boxes_, 1):
    img = draw_boxes(box)
    subplot = fig.add_subplot(4, 2, i)
    subplot.set_title('{} {}x{}'.format(box['filename'], img.shape[0], img.shape[1]))
    plt.imshow(img);

# %% [markdown]
# ### Распределение размеров разметки

# %%
annotations = sum([box['annotations']
                   for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %% [markdown]
# # Экстрактор признаков

# %%
from tensorflow.keras.applications import vgg16

IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = vgg16.VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
    
feature_tensor = features.layers[-1].output
print(feature_tensor.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# (None, 23, 37, 512)

# %% [markdown]
# # Сетка якорей (anchor grid)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])
print(FEATURE_SHAPE)

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

# сетка якорей, размер определяется соотношением 
# размера входного изображения и размером тензора признаков
ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]
# Out:
# (23, 37)

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 12), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        label = fish_classes == rect['class']
                
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]
            
        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = np.array([*label, 1., dx, dy, dw, dh])

    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            
            label = np.empty(len(fish_classes))
            
            *label, digit, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(digit)
            label = softmax(label)

            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf,
                                   'label': np.argmax(_sigmoid(label)),
                                   'labels': label })
    return rectangles

def non_max_suppression(rectangles, max_output_size, iou_threshold=0.5):
    if not rectangles:
        return rectangles
    
    boxes = [[r['y'],
              r['x'],
              r['y'] + r['height'],
              r['x'] + r['width']] for r in rectangles]
    scores = [r['conf'] for r in rectangles]
    indices = tf.image.non_max_suppression(np.array(boxes),
                                           np.array(scores),
                                           max_output_size,
                                           iou_threshold)
    
    return [rectangles[i] for i in indices]

# %% [markdown]
# ### Валидация энкодинга/декодинга якорей

# %%
annotation = boxes['other'][3]

encoded = encode_anchors(annotation,
                         img_shape=(IMG_HEIGHT, IMG_WIDTH),
                         iou_thr=0.1)

decoded = decode_prediction(encoded, conf_thr=0.7)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(annotation, decoded))
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %% [markdown]
# ## Функция потерь

# %%
num_classes = len(fish_classes)

K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    
    conf_loss = K.binary_crossentropy(y_true[..., num_classes], 
                                      y_pred[..., num_classes],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., num_classes + 1:] - y_pred[..., num_classes + 1:])
    square_loss = 0.5 * K.square(y_true[..., num_classes + 1:] - y_pred[..., num_classes + 1:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)


def class_loss(y_tr, y_pr, alpha=0.25, gamma=2.0):
    
    y_true = y_tr[..., :num_classes]
    y_pred = y_pr[..., :num_classes]

    cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
        labels=y_true, logits=y_pred
    )
    probs = tf.nn.softmax(y_pred)
    alpha = tf.where(tf.equal(y_true, 1.0), alpha, (1.0 - alpha))
    pt = tf.where(tf.equal(y_true, 1.0), probs, 1 - probs)
    loss = alpha * tf.pow(1.0 - pt, gamma) * cross_entropy
    
    return tf.reduce_sum(loss, axis=-1)

def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    y_true = K.reshape(y_true, (batch_size, -1, num_classes + 5))
    y_pred = K.reshape(y_pred, (batch_size, -1, num_classes + 5))
    
    # TODO: добавьте функцию потерь для классификации детекции
    classification_loss = class_loss(y_true, y_pred)

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)

    # positive examples loss
    pos_class_loss = K.sum(classification_loss * y_true[..., num_classes], axis=-1)
    pos_conf_loss = K.sum(conf_loss * y_true[..., num_classes], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., num_classes], axis=-1)

    # negative examples loss
    anchors = K.shape(y_true)[1]

    num_pos = K.sum(y_true[..., num_classes], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., num_classes]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    classification_loss = pos_class_loss / (num_pos + 1e-32)
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
   
    return total_conf_loss + 0.5 * loc_loss + classification_loss

# %% [markdown]
# ## Загрузка данных

# %%
from random import shuffle

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, vgg16.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=32):
    boxes = sum(boxes.values(), [])
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %% [markdown]
# ## Добавляем выход детектора

# %%
output = tf.keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
output = tf.keras.layers.Conv2D(num_classes + 5,
                                kernel_size=(1, 1), 
                                activation='linear',
                                kernel_regularizer='l2')(output)

model = tf.keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 750, 1200, 3)]    0
#
#  block1_conv1 (Conv2D)       (None, 750, 1200, 64)     1792
#
#  block1_conv2 (Conv2D)       (None, 750, 1200, 64)     36928
#
#  block1_pool (MaxPooling2D)  (None, 375, 600, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 375, 600, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 375, 600, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 187, 300, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 187, 300, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 93, 150, 256)      0
#
#  block4_conv1 (Conv2D)       (None, 93, 150, 512)      1180160
#
#  block4_conv2 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_conv3 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_pool (MaxPooling2D)  (None, 46, 75, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 23, 37, 512)       0
#
#  batch_normalization (BatchN  (None, 23, 37, 512)      2048
#  ormalization)
#
#  conv2d (Conv2D)             (None, 23, 37, 12)        6156
#
# =================================================================
# Total params: 14,722,892
# Trainable params: 7,086,604
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %% [markdown]
# ## Обучение

# %%
lr =3e-4
BATCH_SIZE = 5
EPOCHS = 10

# %%
def lr_exp_decay(epoch, lr):
    k = 0.5
    #return lr * np.exp(-k*epoch)
    return lr / 2**epoch

optimizer = tf.keras.optimizers.Adam(learning_rate=lr, decay=1e-6)
model.compile(optimizer=optimizer, 
              loss=total_loss,
              metrics=[confidence_loss, class_loss, smooth_l1])


gen = data_generator(boxes, batch_size=BATCH_SIZE)
steps_per_epoch = sum(map(len, boxes.values()), 0) / BATCH_SIZE

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/fish/fishdetector_wh.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=True,
    mode='auto',
    save_freq=50)

# %%
model.fit(gen, 
          steps_per_epoch=steps_per_epoch,
          epochs=EPOCHS,
          callbacks=[checkpoint]) #, tf.keras.callbacks.LearningRateScheduler(lr_exp_decay, verbose=1)])
# Out:
# Epoch 1/10
#  49/662 [=>............................] - ETA: 6:36 - loss: 1.5066 - confidence_loss: 0.6430 - class_loss: 0.2357 - smooth_l1: 0.3795
# Epoch 1: loss improved from inf to 1.49564, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  99/662 [===>..........................] - ETA: 6:08 - loss: 1.2236 - confidence_loss: 0.5686 - class_loss: 0.2321 - smooth_l1: 0.3970
# Epoch 1: loss improved from 1.49564 to 1.21943, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 149/662 [=====>........................] - ETA: 5:35 - loss: 1.0806 - confidence_loss: 0.5006 - class_loss: 0.2162 - smooth_l1: 0.4023
# Epoch 1: loss improved from 1.21943 to 1.07810, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 199/662 [========>.....................] - ETA: 5:03 - loss: 0.9773 - confidence_loss: 0.4387 - class_loss: 0.2113 - smooth_l1: 0.3954
# Epoch 1: loss improved from 1.07810 to 0.97557, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 249/662 [==========>...................] - ETA: 4:31 - loss: 0.9109 - confidence_loss: 0.3855 - class_loss: 0.2069 - smooth_l1: 0.3986
# Epoch 1: loss improved from 0.97557 to 0.91003, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 299/662 [============>.................] - ETA: 3:58 - loss: 0.8493 - confidence_loss: 0.3411 - class_loss: 0.2050 - smooth_l1: 0.4029
# Epoch 1: loss improved from 0.91003 to 0.84796, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 349/662 [==============>...............] - ETA: 3:25 - loss: 0.7936 - confidence_loss: 0.3038 - class_loss: 0.2072 - smooth_l1: 0.3992
# Epoch 1: loss improved from 0.84796 to 0.79261, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 399/662 [=================>............] - ETA: 2:52 - loss: 0.7472 - confidence_loss: 0.2733 - class_loss: 0.2102 - smooth_l1: 0.3929
# Epoch 1: loss improved from 0.79261 to 0.74621, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 449/662 [===================>..........] - ETA: 2:20 - loss: 0.7109 - confidence_loss: 0.2485 - class_loss: 0.2119 - smooth_l1: 0.3884
# Epoch 1: loss improved from 0.74621 to 0.71031, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 499/662 [=====================>........] - ETA: 1:47 - loss: 0.6778 - confidence_loss: 0.2278 - class_loss: 0.2105 - smooth_l1: 0.3852
# Epoch 1: loss improved from 0.71031 to 0.67705, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 549/662 [=======================>......] - ETA: 1:14 - loss: 0.6505 - confidence_loss: 0.2102 - class_loss: 0.2085 - smooth_l1: 0.3801
# Epoch 1: loss improved from 0.67705 to 0.65014, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 599/662 [==========================>...] - ETA: 41s - loss: 0.6275 - confidence_loss: 0.1955 - class_loss: 0.2068 - smooth_l1: 0.3788
# Epoch 1: loss improved from 0.65014 to 0.62695, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 649/662 [============================>.] - ETA: 8s - loss: 0.6060 - confidence_loss: 0.1828 - class_loss: 0.2042 - smooth_l1: 0.3766
# Epoch 1: loss improved from 0.62695 to 0.60545, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 662/662 [==============================] - 438s 658ms/step - loss: 0.6001 - confidence_loss: 0.1795 - class_loss: 0.2036 - smooth_l1: 0.3759
# Epoch 2/10
#  36/662 [>.............................] - ETA: 6:43 - loss: 0.2974 - confidence_loss: 0.0272 - class_loss: 0.1683 - smooth_l1: 0.3345
# Epoch 2: loss improved from 0.60545 to 0.29728, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  86/662 [==>...........................] - ETA: 6:17 - loss: 0.3003 - confidence_loss: 0.0255 - class_loss: 0.1674 - smooth_l1: 0.2971
# Epoch 2: loss did not improve from 0.29728
# 136/662 [=====>........................] - ETA: 5:42 - loss: 0.2960 - confidence_loss: 0.0246 - class_loss: 0.1675 - smooth_l1: 0.2894
# Epoch 2: loss improved from 0.29728 to 0.29697, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 186/662 [=======>......................] - ETA: 5:10 - loss: 0.3002 - confidence_loss: 0.0240 - class_loss: 0.1651 - smooth_l1: 0.2911
# Epoch 2: loss did not improve from 0.29697
# 236/662 [=========>....................] - ETA: 4:37 - loss: 0.2952 - confidence_loss: 0.0235 - class_loss: 0.1696 - smooth_l1: 0.2894
# Epoch 2: loss improved from 0.29697 to 0.29505, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 286/662 [===========>..................] - ETA: 4:05 - loss: 0.2917 - confidence_loss: 0.0231 - class_loss: 0.1710 - smooth_l1: 0.2878
# Epoch 2: loss improved from 0.29505 to 0.29136, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 336/662 [==============>...............] - ETA: 3:33 - loss: 0.2873 - confidence_loss: 0.0227 - class_loss: 0.1704 - smooth_l1: 0.2801
# Epoch 2: loss improved from 0.29136 to 0.28722, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 386/662 [================>.............] - ETA: 3:00 - loss: 0.2839 - confidence_loss: 0.0223 - class_loss: 0.1693 - smooth_l1: 0.2698
# Epoch 2: loss improved from 0.28722 to 0.28446, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 436/662 [==================>...........] - ETA: 2:27 - loss: 0.2851 - confidence_loss: 0.0220 - class_loss: 0.1691 - smooth_l1: 0.2609
# Epoch 2: loss did not improve from 0.28446
# 486/662 [=====================>........] - ETA: 1:55 - loss: 0.2843 - confidence_loss: 0.0217 - class_loss: 0.1688 - smooth_l1: 0.2564
# Epoch 2: loss improved from 0.28446 to 0.28415, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 536/662 [=======================>......] - ETA: 1:22 - loss: 0.2845 - confidence_loss: 0.0215 - class_loss: 0.1688 - smooth_l1: 0.2499
# Epoch 2: loss did not improve from 0.28415
# 586/662 [=========================>....] - ETA: 49s - loss: 0.2817 - confidence_loss: 0.0213 - class_loss: 0.1708 - smooth_l1: 0.2420
# Epoch 2: loss improved from 0.28415 to 0.28176, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 636/662 [===========================>..] - ETA: 17s - loss: 0.2829 - confidence_loss: 0.0211 - class_loss: 0.1724 - smooth_l1: 0.2361
# Epoch 2: loss did not improve from 0.28176
# 662/662 [==============================] - 433s 653ms/step - loss: 0.2811 - confidence_loss: 0.0210 - class_loss: 0.1734 - smooth_l1: 0.2338
# Epoch 3/10
#  23/662 [>.............................] - ETA: 6:53 - loss: 0.2175 - confidence_loss: 0.0173 - class_loss: 0.1885 - smooth_l1: 0.1885
# Epoch 3: loss improved from 0.28176 to 0.21536, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  73/662 [==>...........................] - ETA: 6:25 - loss: 0.2355 - confidence_loss: 0.0171 - class_loss: 0.1854 - smooth_l1: 0.1898
# Epoch 3: loss did not improve from 0.21536
# 123/662 [====>.........................] - ETA: 5:50 - loss: 0.2263 - confidence_loss: 0.0166 - class_loss: 0.1824 - smooth_l1: 0.1770
# Epoch 3: loss did not improve from 0.21536
# 173/662 [======>.......................] - ETA: 5:17 - loss: 0.2216 - confidence_loss: 0.0161 - class_loss: 0.1779 - smooth_l1: 0.1732
# Epoch 3: loss did not improve from 0.21536
# 223/662 [=========>....................] - ETA: 4:44 - loss: 0.2165 - confidence_loss: 0.0157 - class_loss: 0.1749 - smooth_l1: 0.1701
# Epoch 3: loss did not improve from 0.21536
# 273/662 [===========>..................] - ETA: 4:11 - loss: 0.2169 - confidence_loss: 0.0155 - class_loss: 0.1737 - smooth_l1: 0.1695
# Epoch 3: loss did not improve from 0.21536
# 323/662 [=============>................] - ETA: 3:39 - loss: 0.2184 - confidence_loss: 0.0153 - class_loss: 0.1715 - smooth_l1: 0.1735
# Epoch 3: loss did not improve from 0.21536
# 373/662 [===============>..............] - ETA: 3:06 - loss: 0.2157 - confidence_loss: 0.0150 - class_loss: 0.1698 - smooth_l1: 0.1744
# Epoch 3: loss did not improve from 0.21536
# 423/662 [==================>...........] - ETA: 2:34 - loss: 0.2148 - confidence_loss: 0.0149 - class_loss: 0.1681 - smooth_l1: 0.1701
# Epoch 3: loss improved from 0.21536 to 0.21475, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 473/662 [====================>.........] - ETA: 2:02 - loss: 0.2154 - confidence_loss: 0.0147 - class_loss: 0.1668 - smooth_l1: 0.1621
# Epoch 3: loss did not improve from 0.21475
# 523/662 [======================>.......] - ETA: 1:30 - loss: 0.2178 - confidence_loss: 0.0146 - class_loss: 0.1650 - smooth_l1: 0.1570
# Epoch 3: loss did not improve from 0.21475
# 573/662 [========================>.....] - ETA: 57s - loss: 0.2168 - confidence_loss: 0.0145 - class_loss: 0.1628 - smooth_l1: 0.1539
# Epoch 3: loss did not improve from 0.21475
# 623/662 [===========================>..] - ETA: 25s - loss: 0.2158 - confidence_loss: 0.0144 - class_loss: 0.1614 - smooth_l1: 0.1500
# Epoch 3: loss did not improve from 0.21475
# 662/662 [==============================] - 429s 647ms/step - loss: 0.2157 - confidence_loss: 0.0143 - class_loss: 0.1610 - smooth_l1: 0.1474
# Epoch 4/10
#  10/662 [..............................] - ETA: 7:01 - loss: 0.1886 - confidence_loss: 0.0128 - class_loss: 0.1628 - smooth_l1: 0.1127
# Epoch 4: loss improved from 0.21475 to 0.18673, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  60/662 [=>............................] - ETA: 6:35 - loss: 0.1670 - confidence_loss: 0.0122 - class_loss: 0.1562 - smooth_l1: 0.1129
# Epoch 4: loss improved from 0.18673 to 0.16929, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 110/662 [===>..........................] - ETA: 6:03 - loss: 0.1683 - confidence_loss: 0.0119 - class_loss: 0.1514 - smooth_l1: 0.1033
# Epoch 4: loss improved from 0.16929 to 0.16793, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 160/662 [======>.......................] - ETA: 5:30 - loss: 0.1722 - confidence_loss: 0.0117 - class_loss: 0.1498 - smooth_l1: 0.0963
# Epoch 4: loss did not improve from 0.16793
# 210/662 [========>.....................] - ETA: 4:56 - loss: 0.1727 - confidence_loss: 0.0115 - class_loss: 0.1480 - smooth_l1: 0.0953
# Epoch 4: loss did not improve from 0.16793
# 260/662 [==========>...................] - ETA: 4:22 - loss: 0.1746 - confidence_loss: 0.0114 - class_loss: 0.1466 - smooth_l1: 0.0969
# Epoch 4: loss did not improve from 0.16793
# 310/662 [=============>................] - ETA: 3:49 - loss: 0.1731 - confidence_loss: 0.0113 - class_loss: 0.1457 - smooth_l1: 0.0998
# Epoch 4: loss did not improve from 0.16793
# 360/662 [===============>..............] - ETA: 3:16 - loss: 0.1742 - confidence_loss: 0.0111 - class_loss: 0.1458 - smooth_l1: 0.1008
# Epoch 4: loss did not improve from 0.16793
# 410/662 [=================>............] - ETA: 2:44 - loss: 0.1734 - confidence_loss: 0.0110 - class_loss: 0.1449 - smooth_l1: 0.1020
# Epoch 4: loss did not improve from 0.16793
# 460/662 [===================>..........] - ETA: 2:11 - loss: 0.1733 - confidence_loss: 0.0109 - class_loss: 0.1447 - smooth_l1: 0.0998
# Epoch 4: loss did not improve from 0.16793
# 510/662 [======================>.......] - ETA: 1:38 - loss: 0.1749 - confidence_loss: 0.0109 - class_loss: 0.1444 - smooth_l1: 0.0972
# Epoch 4: loss did not improve from 0.16793
# 560/662 [========================>.....] - ETA: 1:06 - loss: 0.1751 - confidence_loss: 0.0108 - class_loss: 0.1437 - smooth_l1: 0.0945
# Epoch 4: loss did not improve from 0.16793
# 610/662 [==========================>...] - ETA: 33s - loss: 0.1769 - confidence_loss: 0.0109 - class_loss: 0.1442 - smooth_l1: 0.0919
# Epoch 4: loss did not improve from 0.16793
# 660/662 [============================>.] - ETA: 1s - loss: 0.1783 - confidence_loss: 0.0109 - class_loss: 0.1445 - smooth_l1: 0.0899
# Epoch 4: loss did not improve from 0.16793
# 662/662 [==============================] - 430s 649ms/step - loss: 0.1785 - confidence_loss: 0.0109 - class_loss: 0.1445 - smooth_l1: 0.0897
# Epoch 5/10
#  47/662 [=>............................] - ETA: 6:35 - loss: 0.1430 - confidence_loss: 0.0100 - class_loss: 0.1397 - smooth_l1: 0.0603
# Epoch 5: loss improved from 0.16793 to 0.14478, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  97/662 [===>..........................] - ETA: 6:08 - loss: 0.1428 - confidence_loss: 0.0097 - class_loss: 0.1429 - smooth_l1: 0.0556
# Epoch 5: loss improved from 0.14478 to 0.14255, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 147/662 [=====>........................] - ETA: 5:37 - loss: 0.1452 - confidence_loss: 0.0095 - class_loss: 0.1450 - smooth_l1: 0.0541
# Epoch 5: loss did not improve from 0.14255
# 197/662 [=======>......................] - ETA: 5:03 - loss: 0.1424 - confidence_loss: 0.0094 - class_loss: 0.1431 - smooth_l1: 0.0559
# Epoch 5: loss improved from 0.14255 to 0.14217, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 247/662 [==========>...................] - ETA: 4:31 - loss: 0.1429 - confidence_loss: 0.0092 - class_loss: 0.1411 - smooth_l1: 0.0571
# Epoch 5: loss did not improve from 0.14217
# 297/662 [============>.................] - ETA: 3:58 - loss: 0.1417 - confidence_loss: 0.0090 - class_loss: 0.1428 - smooth_l1: 0.0585
# Epoch 5: loss improved from 0.14217 to 0.14196, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 347/662 [==============>...............] - ETA: 3:25 - loss: 0.1455 - confidence_loss: 0.0089 - class_loss: 0.1425 - smooth_l1: 0.0574
# Epoch 5: loss did not improve from 0.14196
# 397/662 [================>.............] - ETA: 2:52 - loss: 0.1471 - confidence_loss: 0.0088 - class_loss: 0.1424 - smooth_l1: 0.0573
# Epoch 5: loss did not improve from 0.14196
# 447/662 [===================>..........] - ETA: 2:20 - loss: 0.1474 - confidence_loss: 0.0087 - class_loss: 0.1428 - smooth_l1: 0.0592
# Epoch 5: loss did not improve from 0.14196
# 497/662 [=====================>........] - ETA: 1:47 - loss: 0.1479 - confidence_loss: 0.0087 - class_loss: 0.1430 - smooth_l1: 0.0586
# Epoch 5: loss did not improve from 0.14196
# 547/662 [=======================>......] - ETA: 1:14 - loss: 0.1499 - confidence_loss: 0.0086 - class_loss: 0.1424 - smooth_l1: 0.0605
# Epoch 5: loss did not improve from 0.14196
# 597/662 [==========================>...] - ETA: 42s - loss: 0.1506 - confidence_loss: 0.0086 - class_loss: 0.1424 - smooth_l1: 0.0624
# Epoch 5: loss did not improve from 0.14196
# 647/662 [============================>.] - ETA: 9s - loss: 0.1528 - confidence_loss: 0.0086 - class_loss: 0.1422 - smooth_l1: 0.0662
# Epoch 5: loss did not improve from 0.14196
# 662/662 [==============================] - 430s 649ms/step - loss: 0.1540 - confidence_loss: 0.0086 - class_loss: 0.1425 - smooth_l1: 0.0673
# Epoch 6/10
#  34/662 [>.............................] - ETA: 6:44 - loss: 0.1348 - confidence_loss: 0.0076 - class_loss: 0.1404 - smooth_l1: 0.0938
# Epoch 6: loss improved from 0.14196 to 0.13728, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  84/662 [==>...........................] - ETA: 6:19 - loss: 0.1379 - confidence_loss: 0.0077 - class_loss: 0.1345 - smooth_l1: 0.0828
# Epoch 6: loss did not improve from 0.13728
# 134/662 [=====>........................] - ETA: 5:44 - loss: 0.1342 - confidence_loss: 0.0075 - class_loss: 0.1367 - smooth_l1: 0.0832
# Epoch 6: loss improved from 0.13728 to 0.13410, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 184/662 [=======>......................] - ETA: 5:12 - loss: 0.1388 - confidence_loss: 0.0074 - class_loss: 0.1377 - smooth_l1: 0.0811
# Epoch 6: loss did not improve from 0.13410
# 234/662 [=========>....................] - ETA: 4:38 - loss: 0.1377 - confidence_loss: 0.0074 - class_loss: 0.1359 - smooth_l1: 0.0743
# Epoch 6: loss did not improve from 0.13410
# 284/662 [===========>..................] - ETA: 4:06 - loss: 0.1418 - confidence_loss: 0.0073 - class_loss: 0.1416 - smooth_l1: 0.0717
# Epoch 6: loss did not improve from 0.13410
# 334/662 [==============>...............] - ETA: 3:33 - loss: 0.1442 - confidence_loss: 0.0073 - class_loss: 0.1436 - smooth_l1: 0.0738
# Epoch 6: loss did not improve from 0.13410
# 384/662 [================>.............] - ETA: 3:00 - loss: 0.1441 - confidence_loss: 0.0073 - class_loss: 0.1437 - smooth_l1: 0.0708
# Epoch 6: loss did not improve from 0.13410
# 434/662 [==================>...........] - ETA: 2:27 - loss: 0.1427 - confidence_loss: 0.0072 - class_loss: 0.1428 - smooth_l1: 0.0686
# Epoch 6: loss did not improve from 0.13410
# 484/662 [====================>.........] - ETA: 1:55 - loss: 0.1442 - confidence_loss: 0.0073 - class_loss: 0.1437 - smooth_l1: 0.0678
# Epoch 6: loss did not improve from 0.13410
# 534/662 [=======================>......] - ETA: 1:23 - loss: 0.1432 - confidence_loss: 0.0072 - class_loss: 0.1436 - smooth_l1: 0.0662
# Epoch 6: loss did not improve from 0.13410
# 584/662 [=========================>....] - ETA: 50s - loss: 0.1447 - confidence_loss: 0.0072 - class_loss: 0.1432 - smooth_l1: 0.0667
# Epoch 6: loss did not improve from 0.13410
# 634/662 [===========================>..] - ETA: 18s - loss: 0.1462 - confidence_loss: 0.0072 - class_loss: 0.1429 - smooth_l1: 0.0667
# Epoch 6: loss did not improve from 0.13410
# 662/662 [==============================] - 429s 647ms/step - loss: 0.1460 - confidence_loss: 0.0072 - class_loss: 0.1434 - smooth_l1: 0.0667
# Epoch 7/10
#  21/662 [..............................] - ETA: 6:56 - loss: 0.1075 - confidence_loss: 0.0058 - class_loss: 0.1371 - smooth_l1: 0.0578
# Epoch 7: loss improved from 0.13410 to 0.11267, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  71/662 [==>...........................] - ETA: 6:27 - loss: 0.1149 - confidence_loss: 0.0059 - class_loss: 0.1408 - smooth_l1: 0.0669
# Epoch 7: loss did not improve from 0.11267
# 121/662 [====>.........................] - ETA: 5:52 - loss: 0.1159 - confidence_loss: 0.0059 - class_loss: 0.1444 - smooth_l1: 0.0781
# Epoch 7: loss did not improve from 0.11267
# 171/662 [======>.......................] - ETA: 5:19 - loss: 0.1163 - confidence_loss: 0.0059 - class_loss: 0.1434 - smooth_l1: 0.0840
# Epoch 7: loss did not improve from 0.11267
# 221/662 [=========>....................] - ETA: 4:46 - loss: 0.1152 - confidence_loss: 0.0058 - class_loss: 0.1410 - smooth_l1: 0.0808
# Epoch 7: loss did not improve from 0.11267
# 271/662 [===========>..................] - ETA: 4:13 - loss: 0.1203 - confidence_loss: 0.0059 - class_loss: 0.1402 - smooth_l1: 0.0775
# Epoch 7: loss did not improve from 0.11267
# 321/662 [=============>................] - ETA: 3:41 - loss: 0.1230 - confidence_loss: 0.0059 - class_loss: 0.1387 - smooth_l1: 0.0805
# Epoch 7: loss did not improve from 0.11267
# 371/662 [===============>..............] - ETA: 3:08 - loss: 0.1224 - confidence_loss: 0.0059 - class_loss: 0.1372 - smooth_l1: 0.0845
# Epoch 7: loss did not improve from 0.11267
# 421/662 [==================>...........] - ETA: 2:36 - loss: 0.1235 - confidence_loss: 0.0059 - class_loss: 0.1374 - smooth_l1: 0.0875
# Epoch 7: loss did not improve from 0.11267
# 471/662 [====================>.........] - ETA: 2:03 - loss: 0.1262 - confidence_loss: 0.0059 - class_loss: 0.1370 - smooth_l1: 0.0878
# Epoch 7: loss did not improve from 0.11267
# 521/662 [======================>.......] - ETA: 1:31 - loss: 0.1274 - confidence_loss: 0.0060 - class_loss: 0.1365 - smooth_l1: 0.0869
# Epoch 7: loss did not improve from 0.11267
# 571/662 [========================>.....] - ETA: 59s - loss: 0.1251 - confidence_loss: 0.0059 - class_loss: 0.1359 - smooth_l1: 0.0856
# Epoch 7: loss did not improve from 0.11267
# 621/662 [===========================>..] - ETA: 26s - loss: 0.1269 - confidence_loss: 0.0060 - class_loss: 0.1354 - smooth_l1: 0.0840
# Epoch 7: loss did not improve from 0.11267
# 662/662 [==============================] - 428s 647ms/step - loss: 0.1280 - confidence_loss: 0.0060 - class_loss: 0.1367 - smooth_l1: 0.0825
# Epoch 8/10
#   8/662 [..............................] - ETA: 7:03 - loss: 0.1101 - confidence_loss: 0.0060 - class_loss: 0.1574 - smooth_l1: 0.0587
# Epoch 8: loss improved from 0.11267 to 0.10555, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  58/662 [=>............................] - ETA: 6:36 - loss: 0.1087 - confidence_loss: 0.0056 - class_loss: 0.1442 - smooth_l1: 0.0866
# Epoch 8: loss did not improve from 0.10555
# 108/662 [===>..........................] - ETA: 6:00 - loss: 0.1077 - confidence_loss: 0.0054 - class_loss: 0.1376 - smooth_l1: 0.0738
# Epoch 8: loss did not improve from 0.10555
# 158/662 [======>.......................] - ETA: 5:27 - loss: 0.1127 - confidence_loss: 0.0055 - class_loss: 0.1352 - smooth_l1: 0.0649
# Epoch 8: loss did not improve from 0.10555
# 208/662 [========>.....................] - ETA: 4:54 - loss: 0.1105 - confidence_loss: 0.0055 - class_loss: 0.1320 - smooth_l1: 0.0605
# Epoch 8: loss did not improve from 0.10555
# 258/662 [==========>...................] - ETA: 4:22 - loss: 0.1110 - confidence_loss: 0.0055 - class_loss: 0.1308 - smooth_l1: 0.0572
# Epoch 8: loss did not improve from 0.10555
# 308/662 [============>.................] - ETA: 3:49 - loss: 0.1083 - confidence_loss: 0.0054 - class_loss: 0.1302 - smooth_l1: 0.0562
# Epoch 8: loss did not improve from 0.10555
# 358/662 [===============>..............] - ETA: 3:17 - loss: 0.1093 - confidence_loss: 0.0053 - class_loss: 0.1295 - smooth_l1: 0.0561
# Epoch 8: loss did not improve from 0.10555
# 408/662 [=================>............] - ETA: 2:44 - loss: 0.1107 - confidence_loss: 0.0054 - class_loss: 0.1288 - smooth_l1: 0.0539
# Epoch 8: loss did not improve from 0.10555
# 458/662 [===================>..........] - ETA: 2:12 - loss: 0.1114 - confidence_loss: 0.0054 - class_loss: 0.1275 - smooth_l1: 0.0521
# Epoch 8: loss did not improve from 0.10555
# 508/662 [======================>.......] - ETA: 1:39 - loss: 0.1111 - confidence_loss: 0.0054 - class_loss: 0.1272 - smooth_l1: 0.0508
# Epoch 8: loss did not improve from 0.10555
# 558/662 [========================>.....] - ETA: 1:07 - loss: 0.1112 - confidence_loss: 0.0054 - class_loss: 0.1269 - smooth_l1: 0.0496
# Epoch 8: loss did not improve from 0.10555
# 608/662 [==========================>...] - ETA: 35s - loss: 0.1123 - confidence_loss: 0.0054 - class_loss: 0.1261 - smooth_l1: 0.0489
# Epoch 8: loss did not improve from 0.10555
# 658/662 [============================>.] - ETA: 2s - loss: 0.1141 - confidence_loss: 0.0054 - class_loss: 0.1254 - smooth_l1: 0.0486
# Epoch 8: loss did not improve from 0.10555
# 662/662 [==============================] - 429s 647ms/step - loss: 0.1141 - confidence_loss: 0.0054 - class_loss: 0.1254 - smooth_l1: 0.0485
# Epoch 9/10
#  45/662 [=>............................] - ETA: 6:38 - loss: 0.1034 - confidence_loss: 0.0054 - class_loss: 0.1274 - smooth_l1: 0.0287
# Epoch 9: loss improved from 0.10555 to 0.10361, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  95/662 [===>..........................] - ETA: 6:10 - loss: 0.0944 - confidence_loss: 0.0051 - class_loss: 0.1227 - smooth_l1: 0.0282
# Epoch 9: loss improved from 0.10361 to 0.09414, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
# 145/662 [=====>........................] - ETA: 5:38 - loss: 0.0967 - confidence_loss: 0.0049 - class_loss: 0.1190 - smooth_l1: 0.0296
# Epoch 9: loss did not improve from 0.09414
# 195/662 [=======>......................] - ETA: 5:05 - loss: 0.0985 - confidence_loss: 0.0049 - class_loss: 0.1184 - smooth_l1: 0.0349
# Epoch 9: loss did not improve from 0.09414
# 245/662 [==========>...................] - ETA: 4:31 - loss: 0.1023 - confidence_loss: 0.0049 - class_loss: 0.1192 - smooth_l1: 0.0363
# Epoch 9: loss did not improve from 0.09414
# 295/662 [============>.................] - ETA: 3:58 - loss: 0.1030 - confidence_loss: 0.0049 - class_loss: 0.1183 - smooth_l1: 0.0370
# Epoch 9: loss did not improve from 0.09414
# 345/662 [==============>...............] - ETA: 3:26 - loss: 0.1046 - confidence_loss: 0.0049 - class_loss: 0.1181 - smooth_l1: 0.0373
# Epoch 9: loss did not improve from 0.09414
# 395/662 [================>.............] - ETA: 2:53 - loss: 0.1054 - confidence_loss: 0.0049 - class_loss: 0.1180 - smooth_l1: 0.0379
# Epoch 9: loss did not improve from 0.09414
# 445/662 [===================>..........] - ETA: 2:20 - loss: 0.1053 - confidence_loss: 0.0050 - class_loss: 0.1181 - smooth_l1: 0.0377
# Epoch 9: loss did not improve from 0.09414
# 495/662 [=====================>........] - ETA: 1:48 - loss: 0.1050 - confidence_loss: 0.0050 - class_loss: 0.1179 - smooth_l1: 0.0372
# Epoch 9: loss did not improve from 0.09414
# 545/662 [=======================>......] - ETA: 1:16 - loss: 0.1052 - confidence_loss: 0.0050 - class_loss: 0.1182 - smooth_l1: 0.0379
# Epoch 9: loss did not improve from 0.09414
# 595/662 [=========================>....] - ETA: 43s - loss: 0.1053 - confidence_loss: 0.0049 - class_loss: 0.1183 - smooth_l1: 0.0383
# Epoch 9: loss did not improve from 0.09414
# 645/662 [============================>.] - ETA: 11s - loss: 0.1063 - confidence_loss: 0.0049 - class_loss: 0.1180 - smooth_l1: 0.0383
# Epoch 9: loss did not improve from 0.09414
# 662/662 [==============================] - 429s 648ms/step - loss: 0.1064 - confidence_loss: 0.0049 - class_loss: 0.1178 - smooth_l1: 0.0383
# Epoch 10/10
#  32/662 [>.............................] - ETA: 6:47 - loss: 0.0727 - confidence_loss: 0.0041 - class_loss: 0.1073 - smooth_l1: 0.0379
# Epoch 10: loss improved from 0.09414 to 0.07533, saving model to /content/drive/MyDrive/fish/fishdetector_wh.hdf5
#  82/662 [==>...........................] - ETA: 6:19 - loss: 0.0853 - confidence_loss: 0.0041 - class_loss: 0.1062 - smooth_l1: 0.0408
# Epoch 10: loss did not improve from 0.07533
# 132/662 [====>.........................] - ETA: 5:45 - loss: 0.0911 - confidence_loss: 0.0041 - class_loss: 0.1072 - smooth_l1: 0.0393
# Epoch 10: loss did not improve from 0.07533
# 182/662 [=======>......................] - ETA: 5:12 - loss: 0.0932 - confidence_loss: 0.0042 - class_loss: 0.1084 - smooth_l1: 0.0394
# Epoch 10: loss did not improve from 0.07533
# 232/662 [=========>....................] - ETA: 4:39 - loss: 0.0986 - confidence_loss: 0.0043 - class_loss: 0.1093 - smooth_l1: 0.0429
# Epoch 10: loss did not improve from 0.07533
# 282/662 [===========>..................] - ETA: 4:06 - loss: 0.0986 - confidence_loss: 0.0044 - class_loss: 0.1108 - smooth_l1: 0.0460
# Epoch 10: loss did not improve from 0.07533
# 332/662 [==============>...............] - ETA: 3:34 - loss: 0.0995 - confidence_loss: 0.0044 - class_loss: 0.1112 - smooth_l1: 0.0499
# Epoch 10: loss did not improve from 0.07533
# 382/662 [================>.............] - ETA: 3:01 - loss: 0.0998 - confidence_loss: 0.0044 - class_loss: 0.1110 - smooth_l1: 0.0535
# Epoch 10: loss did not improve from 0.07533
# 432/662 [==================>...........] - ETA: 2:29 - loss: 0.1002 - confidence_loss: 0.0045 - class_loss: 0.1110 - smooth_l1: 0.0559
# Epoch 10: loss did not improve from 0.07533
# 482/662 [====================>.........] - ETA: 1:56 - loss: 0.1023 - confidence_loss: 0.0045 - class_loss: 0.1110 - smooth_l1: 0.0569
# Epoch 10: loss did not improve from 0.07533
# 532/662 [=======================>......] - ETA: 1:24 - loss: 0.1030 - confidence_loss: 0.0045 - class_loss: 0.1113 - smooth_l1: 0.0557
# Epoch 10: loss did not improve from 0.07533
# 582/662 [=========================>....] - ETA: 52s - loss: 0.1029 - confidence_loss: 0.0045 - class_loss: 0.1112 - smooth_l1: 0.0542
# Epoch 10: loss did not improve from 0.07533
# 632/662 [===========================>..] - ETA: 19s - loss: 0.1025 - confidence_loss: 0.0045 - class_loss: 0.1111 - smooth_l1: 0.0530
# Epoch 10: loss did not improve from 0.07533
# 662/662 [==============================] - 429s 648ms/step - loss: 0.1023 - confidence_loss: 0.0045 - class_loss: 0.1110 - smooth_l1: 0.0523

# %% [markdown]
# ## Результат работы детектора

# %%
model.load_weights('/content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5')
#model = tf.keras.models.load_model('/content/drive/MyDrive/fish/fishdetector_wh.hdf5')

# %% [markdown]
# Продемонстрируем работу модели на тренировочных данных (зеленым обозначена исходная разметка и класс; красным - предсказанный моделью класс и область размещения):

# %%
annotation = boxes['other'][3]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.1)

decoded = non_max_suppression(decoded,
                              max_output_size=2,
                              iou_threshold=0.5)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));

# %% [markdown]
# На данной фотографии две рыбы и две области, на деле модель более-менее справляется только с первой областью, погрешность для второй и следующих высокая, поэтому ограничимся только ею.

# %% [markdown]
# Ещё несколько примеров на тренировочных данных для разных классов:

# %%
# {'filename': filename['filename']}
test_images = [boxes['alb'][1], boxes['alb'][3], boxes['yft'][1],
               boxes['yft'][7], boxes['other'][0], boxes['other'][1],
               boxes['bet'][1], boxes['bet'][6], boxes['shark'][3],
               boxes['shark'][6], boxes['dol'][0], boxes['dol'][1],
               boxes['lag'][0], boxes['lag'][8]
]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename['filename'])

    pred = model.predict(np.array([sample_img,]))
    decoded = decode_prediction(pred[0], conf_thr=0.002)
    decoded = non_max_suppression(decoded,
                                  max_output_size=1,
                                  iou_threshold=0.1)
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes(filename, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание модели {}'.format(filename['filename'].split('/')[-1]));
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Визуализируем предсказание на тесте

# %%
with zipfile.ZipFile("/content/drive/MyDrive/fish/test_stg1.zip","r") as z:
    z.extractall(".")
import py7zr
with py7zr.SevenZipFile("/content/drive/MyDrive/fish/test_stg2.7z", mode='r') as z:
    z.extractall()

# %%
test_images = glob('test_stg1/*.jpg')[10:30]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)

    pred = model.predict(np.array([sample_img,]))
    decoded = decode_prediction(pred[0], conf_thr=0.002)
    decoded = non_max_suppression(decoded,
                                  max_output_size=1,
                                  iou_threshold=0.1)
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename.split('/')[-1]));
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Готовим данные для сабмита

# %%
# TODO: предскажите класс рыбы для фотографии из тестовой выборки
#
# Подготовьте файл с предсказаниями вероятностей для каждой фотографии:
# image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT
# img_00001.jpg,1,0,0,0,0,...,0
# img_00002.jpg,0.3,0.1,0.6,0,...,0

# %%
import re
p = re.compile(r'_(\d+)')
CONF_THR = 0.002

def make_predictions() -> pd.DataFrame:
    df_submit = []

    images_list =glob('test_stg1/*.jpg')
    images_list = sorted(images_list, key = lambda s: int(p.search(s).group(1)))

    for file in tqdm(images_list):
        _, sample_img = load_img(file)
        
        pred = model.predict(np.array([sample_img,]))[0]
        decoded = decode_prediction(pred, conf_thr=CONF_THR)
        decoded = non_max_suppression(decoded,
                              max_output_size=1,
                              iou_threshold=0.5)
        
        row_predict = {}
        
        row_predict['image'] = re.search("img_\d+\.jpg", file)[0]
        #row_predict['conf'] = decoded[0]['conf']
        
        decoded = decoded[0]['labels']
        
        row_predict['ALB'] = decoded[0]
        row_predict['BET'] = decoded[3]
        row_predict['DOL'] = decoded[5]
        row_predict['LAG'] = decoded[6]
        row_predict['NoF'] = 0.123081 # фиксированная вероятность для класса 'No Fishes' из файла sample_submission
        row_predict['OTHER'] = decoded[2]
        row_predict['SHARK'] = decoded[4]
        row_predict['YFT'] = decoded[1]     

        df_submit.append(row_predict)

    images_list = glob('test_stg2/*.jpg')
    images_list = sorted(images_list, key = lambda s: int(p.search(s).group(1)))

    for file in tqdm(images_list):
        _, sample_img = load_img(file)
        
        pred = model.predict(np.array([sample_img,]))[0]
        decoded = decode_prediction(pred, conf_thr=CONF_THR)
        decoded = non_max_suppression(decoded,
                              max_output_size=1,
                              iou_threshold=0.5)
        
        row_predict = {}
        
        row_predict['image'] = 'test_stg2/' + re.search("image_\d+\.jpg", file)[0]
        #row_predict['conf'] = decoded[0]['conf']
        
        decoded = decoded[0]['labels']
        
        row_predict['ALB'] = decoded[0]
        row_predict['BET'] = decoded[3]
        row_predict['DOL'] = decoded[5]
        row_predict['LAG'] = decoded[6]
        row_predict['NoF'] = 0.123081 # фиксированная вероятность для класса 'No Fishes' из файла sample_submission
        row_predict['OTHER'] = decoded[2]
        row_predict['SHARK'] = decoded[4]
        row_predict['YFT'] = decoded[1]
       
        df_submit.append(row_predict)

    return pd.DataFrame.from_dict(df_submit)

# %%
df_submit = make_predictions()
df_submit.to_csv("/content/drive/MyDrive/fish/submit_hw3_upd.csv", index=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/12153 [00:00<?, ?it/s]

# %% [markdown]
# ## Результат на kaggle

# %% [markdown]
# ![submit_hw3.png](data:image/png;base64,...)

# %% [markdown]
# # Дообучение

# %%
lr =1e-5
BATCH_SIZE = 5
EPOCHS = 10

# %%
def lr_exp_decay(epoch, lr):
    k = 0.5
    #return lr * np.exp(-k*epoch)
    return lr / 2**epoch

optimizer = tf.keras.optimizers.Adam(learning_rate=lr, decay=1e-6)
model.compile(optimizer=optimizer, 
              loss=total_loss,
              metrics=[confidence_loss, class_loss, smooth_l1])


gen = data_generator(boxes, batch_size=BATCH_SIZE)
steps_per_epoch = sum(map(len, boxes.values()), 0) / BATCH_SIZE

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=True,
    mode='auto',
    save_freq=50)

# %%
model.fit(gen, 
          steps_per_epoch=steps_per_epoch,
          epochs=EPOCHS,
          callbacks=[checkpoint]) #, tf.keras.callbacks.LearningRateScheduler(lr_exp_decay, verbose=1)])
# Out:
# Epoch 1/10
#  49/662 [=>............................] - ETA: 7:00 - loss: 0.0741 - confidence_loss: 0.0039 - class_loss: 0.1048 - smooth_l1: 0.0379
# Epoch 1: loss improved from inf to 0.07332, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
#  99/662 [===>..........................] - ETA: 6:19 - loss: 0.0762 - confidence_loss: 0.0040 - class_loss: 0.1046 - smooth_l1: 0.0375
# Epoch 1: loss did not improve from 0.07332
# 149/662 [=====>........................] - ETA: 5:45 - loss: 0.0809 - confidence_loss: 0.0041 - class_loss: 0.1049 - smooth_l1: 0.0375
# Epoch 1: loss did not improve from 0.07332
# 199/662 [========>.....................] - ETA: 5:11 - loss: 0.0799 - confidence_loss: 0.0041 - class_loss: 0.1048 - smooth_l1: 0.0374
# Epoch 1: loss did not improve from 0.07332
# 249/662 [==========>...................] - ETA: 4:37 - loss: 0.0811 - confidence_loss: 0.0041 - class_loss: 0.1050 - smooth_l1: 0.0373
# Epoch 1: loss did not improve from 0.07332
# 299/662 [============>.................] - ETA: 4:03 - loss: 0.0831 - confidence_loss: 0.0041 - class_loss: 0.1051 - smooth_l1: 0.0372
# Epoch 1: loss did not improve from 0.07332
# 349/662 [==============>...............] - ETA: 3:30 - loss: 0.0804 - confidence_loss: 0.0040 - class_loss: 0.1051 - smooth_l1: 0.0370
# Epoch 1: loss did not improve from 0.07332
# 399/662 [=================>............] - ETA: 2:56 - loss: 0.0788 - confidence_loss: 0.0040 - class_loss: 0.1050 - smooth_l1: 0.0367
# Epoch 1: loss did not improve from 0.07332
# 449/662 [===================>..........] - ETA: 2:22 - loss: 0.0789 - confidence_loss: 0.0040 - class_loss: 0.1050 - smooth_l1: 0.0365
# Epoch 1: loss did not improve from 0.07332
# 499/662 [=====================>........] - ETA: 1:49 - loss: 0.0777 - confidence_loss: 0.0040 - class_loss: 0.1050 - smooth_l1: 0.0363
# Epoch 1: loss did not improve from 0.07332
# 549/662 [=======================>......] - ETA: 1:15 - loss: 0.0777 - confidence_loss: 0.0040 - class_loss: 0.1050 - smooth_l1: 0.0361
# Epoch 1: loss did not improve from 0.07332
# 599/662 [==========================>...] - ETA: 42s - loss: 0.0763 - confidence_loss: 0.0040 - class_loss: 0.1051 - smooth_l1: 0.0360
# Epoch 1: loss did not improve from 0.07332
# 649/662 [============================>.] - ETA: 8s - loss: 0.0764 - confidence_loss: 0.0040 - class_loss: 0.1052 - smooth_l1: 0.0358
# Epoch 1: loss did not improve from 0.07332
# 662/662 [==============================] - 457s 670ms/step - loss: 0.0762 - confidence_loss: 0.0040 - class_loss: 0.1052 - smooth_l1: 0.0358
# Epoch 2/10
#  36/662 [>.............................] - ETA: 6:58 - loss: 0.0862 - confidence_loss: 0.0040 - class_loss: 0.1062 - smooth_l1: 0.0333
# Epoch 2: loss did not improve from 0.07332
#  86/662 [==>...........................] - ETA: 6:25 - loss: 0.0753 - confidence_loss: 0.0039 - class_loss: 0.1055 - smooth_l1: 0.0331
# Epoch 2: loss did not improve from 0.07332
# 136/662 [=====>........................] - ETA: 5:52 - loss: 0.0704 - confidence_loss: 0.0038 - class_loss: 0.1055 - smooth_l1: 0.0331
# Epoch 2: loss improved from 0.07332 to 0.07052, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 186/662 [=======>......................] - ETA: 5:22 - loss: 0.0677 - confidence_loss: 0.0038 - class_loss: 0.1055 - smooth_l1: 0.0328
# Epoch 2: loss improved from 0.07052 to 0.06786, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 236/662 [=========>....................] - ETA: 4:49 - loss: 0.0662 - confidence_loss: 0.0038 - class_loss: 0.1054 - smooth_l1: 0.0325
# Epoch 2: loss improved from 0.06786 to 0.06606, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 286/662 [===========>..................] - ETA: 4:15 - loss: 0.0660 - confidence_loss: 0.0037 - class_loss: 0.1054 - smooth_l1: 0.0324
# Epoch 2: loss did not improve from 0.06606
# 336/662 [==============>...............] - ETA: 3:41 - loss: 0.0656 - confidence_loss: 0.0037 - class_loss: 0.1054 - smooth_l1: 0.0322
# Epoch 2: loss improved from 0.06606 to 0.06573, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 386/662 [================>.............] - ETA: 3:07 - loss: 0.0667 - confidence_loss: 0.0037 - class_loss: 0.1054 - smooth_l1: 0.0320
# Epoch 2: loss did not improve from 0.06573
# 436/662 [==================>...........] - ETA: 2:33 - loss: 0.0660 - confidence_loss: 0.0037 - class_loss: 0.1053 - smooth_l1: 0.0319
# Epoch 2: loss did not improve from 0.06573
# 486/662 [=====================>........] - ETA: 1:59 - loss: 0.0653 - confidence_loss: 0.0037 - class_loss: 0.1053 - smooth_l1: 0.0318
# Epoch 2: loss improved from 0.06573 to 0.06531, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 536/662 [=======================>......] - ETA: 1:25 - loss: 0.0656 - confidence_loss: 0.0037 - class_loss: 0.1052 - smooth_l1: 0.0317
# Epoch 2: loss did not improve from 0.06531
# 586/662 [=========================>....] - ETA: 51s - loss: 0.0653 - confidence_loss: 0.0037 - class_loss: 0.1052 - smooth_l1: 0.0316
# Epoch 2: loss improved from 0.06531 to 0.06523, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 636/662 [===========================>..] - ETA: 17s - loss: 0.0652 - confidence_loss: 0.0037 - class_loss: 0.1053 - smooth_l1: 0.0315
# Epoch 2: loss improved from 0.06523 to 0.06517, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 662/662 [==============================] - 449s 678ms/step - loss: 0.0645 - confidence_loss: 0.0036 - class_loss: 0.1052 - smooth_l1: 0.0315
# Epoch 3/10
#  23/662 [>.............................] - ETA: 7:08 - loss: 0.0455 - confidence_loss: 0.0033 - class_loss: 0.1038 - smooth_l1: 0.0297
# Epoch 3: loss improved from 0.06517 to 0.04466, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
#  73/662 [==>...........................] - ETA: 6:39 - loss: 0.0497 - confidence_loss: 0.0034 - class_loss: 0.1041 - smooth_l1: 0.0300
# Epoch 3: loss did not improve from 0.04466
# 123/662 [====>.........................] - ETA: 6:03 - loss: 0.0553 - confidence_loss: 0.0035 - class_loss: 0.1040 - smooth_l1: 0.0301
# Epoch 3: loss did not improve from 0.04466
# 173/662 [======>.......................] - ETA: 5:29 - loss: 0.0561 - confidence_loss: 0.0034 - class_loss: 0.1042 - smooth_l1: 0.0301
# Epoch 3: loss did not improve from 0.04466
# 223/662 [=========>....................] - ETA: 4:55 - loss: 0.0565 - confidence_loss: 0.0035 - class_loss: 0.1043 - smooth_l1: 0.0300
# Epoch 3: loss did not improve from 0.04466
# 273/662 [===========>..................] - ETA: 4:21 - loss: 0.0577 - confidence_loss: 0.0035 - class_loss: 0.1044 - smooth_l1: 0.0298
# Epoch 3: loss did not improve from 0.04466
# 323/662 [=============>................] - ETA: 3:47 - loss: 0.0595 - confidence_loss: 0.0035 - class_loss: 0.1043 - smooth_l1: 0.0297
# Epoch 3: loss did not improve from 0.04466
# 373/662 [===============>..............] - ETA: 3:13 - loss: 0.0587 - confidence_loss: 0.0035 - class_loss: 0.1043 - smooth_l1: 0.0296
# Epoch 3: loss did not improve from 0.04466
# 423/662 [==================>...........] - ETA: 2:40 - loss: 0.0573 - confidence_loss: 0.0034 - class_loss: 0.1044 - smooth_l1: 0.0295
# Epoch 3: loss did not improve from 0.04466
# 473/662 [====================>.........] - ETA: 2:06 - loss: 0.0577 - confidence_loss: 0.0034 - class_loss: 0.1044 - smooth_l1: 0.0296
# Epoch 3: loss did not improve from 0.04466
# 523/662 [======================>.......] - ETA: 1:33 - loss: 0.0588 - confidence_loss: 0.0034 - class_loss: 0.1044 - smooth_l1: 0.0296
# Epoch 3: loss did not improve from 0.04466
# 573/662 [========================>.....] - ETA: 59s - loss: 0.0589 - confidence_loss: 0.0034 - class_loss: 0.1044 - smooth_l1: 0.0296
# Epoch 3: loss did not improve from 0.04466
# 623/662 [===========================>..] - ETA: 26s - loss: 0.0589 - confidence_loss: 0.0034 - class_loss: 0.1044 - smooth_l1: 0.0296
# Epoch 3: loss did not improve from 0.04466
# 662/662 [==============================] - 443s 669ms/step - loss: 0.0587 - confidence_loss: 0.0034 - class_loss: 0.1043 - smooth_l1: 0.0296
# Epoch 4/10
#  10/662 [..............................] - ETA: 7:16 - loss: 0.0492 - confidence_loss: 0.0032 - class_loss: 0.1029 - smooth_l1: 0.0289
# Epoch 4: loss did not improve from 0.04466
#  60/662 [=>............................] - ETA: 6:42 - loss: 0.0522 - confidence_loss: 0.0033 - class_loss: 0.1036 - smooth_l1: 0.0292
# Epoch 4: loss did not improve from 0.04466
# 110/662 [===>..........................] - ETA: 6:08 - loss: 0.0527 - confidence_loss: 0.0033 - class_loss: 0.1033 - smooth_l1: 0.0292
# Epoch 4: loss did not improve from 0.04466
# 160/662 [======>.......................] - ETA: 5:35 - loss: 0.0549 - confidence_loss: 0.0033 - class_loss: 0.1034 - smooth_l1: 0.0294
# Epoch 4: loss did not improve from 0.04466
# 210/662 [========>.....................] - ETA: 5:02 - loss: 0.0524 - confidence_loss: 0.0033 - class_loss: 0.1033 - smooth_l1: 0.0292
# Epoch 4: loss did not improve from 0.04466
# 260/662 [==========>...................] - ETA: 4:28 - loss: 0.0524 - confidence_loss: 0.0032 - class_loss: 0.1033 - smooth_l1: 0.0292
# Epoch 4: loss did not improve from 0.04466
# 310/662 [=============>................] - ETA: 3:55 - loss: 0.0513 - confidence_loss: 0.0032 - class_loss: 0.1035 - smooth_l1: 0.0291
# Epoch 4: loss did not improve from 0.04466
# 360/662 [===============>..............] - ETA: 3:22 - loss: 0.0527 - confidence_loss: 0.0033 - class_loss: 0.1033 - smooth_l1: 0.0289
# Epoch 4: loss did not improve from 0.04466
# 410/662 [=================>............] - ETA: 2:48 - loss: 0.0531 - confidence_loss: 0.0033 - class_loss: 0.1033 - smooth_l1: 0.0288
# Epoch 4: loss did not improve from 0.04466
# 460/662 [===================>..........] - ETA: 2:15 - loss: 0.0538 - confidence_loss: 0.0033 - class_loss: 0.1032 - smooth_l1: 0.0288
# Epoch 4: loss did not improve from 0.04466
# 510/662 [======================>.......] - ETA: 1:41 - loss: 0.0537 - confidence_loss: 0.0032 - class_loss: 0.1031 - smooth_l1: 0.0287
# Epoch 4: loss did not improve from 0.04466
# 560/662 [========================>.....] - ETA: 1:08 - loss: 0.0539 - confidence_loss: 0.0032 - class_loss: 0.1031 - smooth_l1: 0.0287
# Epoch 4: loss did not improve from 0.04466
# 610/662 [==========================>...] - ETA: 35s - loss: 0.0539 - confidence_loss: 0.0032 - class_loss: 0.1031 - smooth_l1: 0.0286
# Epoch 4: loss did not improve from 0.04466
# 660/662 [============================>.] - ETA: 1s - loss: 0.0542 - confidence_loss: 0.0032 - class_loss: 0.1030 - smooth_l1: 0.0285
# Epoch 4: loss did not improve from 0.04466
# 662/662 [==============================] - 443s 669ms/step - loss: 0.0542 - confidence_loss: 0.0032 - class_loss: 0.1030 - smooth_l1: 0.0285
# Epoch 5/10
#  47/662 [=>............................] - ETA: 6:51 - loss: 0.0470 - confidence_loss: 0.0030 - class_loss: 0.1030 - smooth_l1: 0.0279
# Epoch 5: loss did not improve from 0.04466
#  97/662 [===>..........................] - ETA: 6:18 - loss: 0.0506 - confidence_loss: 0.0031 - class_loss: 0.1025 - smooth_l1: 0.0276
# Epoch 5: loss did not improve from 0.04466
# 147/662 [=====>........................] - ETA: 5:45 - loss: 0.0478 - confidence_loss: 0.0031 - class_loss: 0.1024 - smooth_l1: 0.0274
# Epoch 5: loss did not improve from 0.04466
# 197/662 [=======>......................] - ETA: 5:11 - loss: 0.0483 - confidence_loss: 0.0031 - class_loss: 0.1023 - smooth_l1: 0.0273
# Epoch 5: loss did not improve from 0.04466
# 247/662 [==========>...................] - ETA: 4:38 - loss: 0.0502 - confidence_loss: 0.0031 - class_loss: 0.1024 - smooth_l1: 0.0272
# Epoch 5: loss did not improve from 0.04466
# 297/662 [============>.................] - ETA: 4:04 - loss: 0.0512 - confidence_loss: 0.0031 - class_loss: 0.1023 - smooth_l1: 0.0272
# Epoch 5: loss did not improve from 0.04466
# 347/662 [==============>...............] - ETA: 3:30 - loss: 0.0516 - confidence_loss: 0.0031 - class_loss: 0.1022 - smooth_l1: 0.0271
# Epoch 5: loss did not improve from 0.04466
# 397/662 [================>.............] - ETA: 2:57 - loss: 0.0516 - confidence_loss: 0.0031 - class_loss: 0.1022 - smooth_l1: 0.0271
# Epoch 5: loss did not improve from 0.04466
# 447/662 [===================>..........] - ETA: 2:24 - loss: 0.0516 - confidence_loss: 0.0031 - class_loss: 0.1021 - smooth_l1: 0.0271
# Epoch 5: loss did not improve from 0.04466
# 497/662 [=====================>........] - ETA: 1:50 - loss: 0.0511 - confidence_loss: 0.0031 - class_loss: 0.1020 - smooth_l1: 0.0270
# Epoch 5: loss did not improve from 0.04466
# 547/662 [=======================>......] - ETA: 1:17 - loss: 0.0511 - confidence_loss: 0.0031 - class_loss: 0.1020 - smooth_l1: 0.0270
# Epoch 5: loss did not improve from 0.04466
# 597/662 [==========================>...] - ETA: 43s - loss: 0.0504 - confidence_loss: 0.0031 - class_loss: 0.1019 - smooth_l1: 0.0269
# Epoch 5: loss did not improve from 0.04466
# 647/662 [============================>.] - ETA: 10s - loss: 0.0508 - confidence_loss: 0.0031 - class_loss: 0.1019 - smooth_l1: 0.0269
# Epoch 5: loss did not improve from 0.04466
# 662/662 [==============================] - 443s 670ms/step - loss: 0.0502 - confidence_loss: 0.0031 - class_loss: 0.1019 - smooth_l1: 0.0269
# Epoch 6/10
#  34/662 [>.............................] - ETA: 6:58 - loss: 0.0538 - confidence_loss: 0.0030 - class_loss: 0.1022 - smooth_l1: 0.0267
# Epoch 6: loss did not improve from 0.04466
#  84/662 [==>...........................] - ETA: 6:25 - loss: 0.0494 - confidence_loss: 0.0030 - class_loss: 0.1014 - smooth_l1: 0.0266
# Epoch 6: loss did not improve from 0.04466
# 134/662 [=====>........................] - ETA: 5:52 - loss: 0.0500 - confidence_loss: 0.0030 - class_loss: 0.1011 - smooth_l1: 0.0263
# Epoch 6: loss did not improve from 0.04466
# 184/662 [=======>......................] - ETA: 5:19 - loss: 0.0497 - confidence_loss: 0.0030 - class_loss: 0.1012 - smooth_l1: 0.0262
# Epoch 6: loss did not improve from 0.04466
# 234/662 [=========>....................] - ETA: 4:46 - loss: 0.0487 - confidence_loss: 0.0030 - class_loss: 0.1011 - smooth_l1: 0.0261
# Epoch 6: loss did not improve from 0.04466
# 284/662 [===========>..................] - ETA: 4:12 - loss: 0.0474 - confidence_loss: 0.0029 - class_loss: 0.1012 - smooth_l1: 0.0261
# Epoch 6: loss did not improve from 0.04466
# 334/662 [==============>...............] - ETA: 3:39 - loss: 0.0466 - confidence_loss: 0.0029 - class_loss: 0.1011 - smooth_l1: 0.0260
# Epoch 6: loss did not improve from 0.04466
# 384/662 [================>.............] - ETA: 3:05 - loss: 0.0475 - confidence_loss: 0.0029 - class_loss: 0.1011 - smooth_l1: 0.0260
# Epoch 6: loss did not improve from 0.04466
# 434/662 [==================>...........] - ETA: 2:32 - loss: 0.0479 - confidence_loss: 0.0029 - class_loss: 0.1011 - smooth_l1: 0.0260
# Epoch 6: loss did not improve from 0.04466
# 484/662 [====================>.........] - ETA: 1:59 - loss: 0.0481 - confidence_loss: 0.0029 - class_loss: 0.1011 - smooth_l1: 0.0260
# Epoch 6: loss did not improve from 0.04466
# 534/662 [=======================>......] - ETA: 1:25 - loss: 0.0483 - confidence_loss: 0.0029 - class_loss: 0.1010 - smooth_l1: 0.0260
# Epoch 6: loss did not improve from 0.04466
# 584/662 [=========================>....] - ETA: 52s - loss: 0.0479 - confidence_loss: 0.0029 - class_loss: 0.1010 - smooth_l1: 0.0259
# Epoch 6: loss did not improve from 0.04466
# 634/662 [===========================>..] - ETA: 18s - loss: 0.0482 - confidence_loss: 0.0029 - class_loss: 0.1009 - smooth_l1: 0.0259
# Epoch 6: loss did not improve from 0.04466
# 662/662 [==============================] - 443s 669ms/step - loss: 0.0481 - confidence_loss: 0.0029 - class_loss: 0.1009 - smooth_l1: 0.0259
# Epoch 7/10
#  21/662 [..............................] - ETA: 7:09 - loss: 0.0520 - confidence_loss: 0.0030 - class_loss: 0.1003 - smooth_l1: 0.0244
# Epoch 7: loss did not improve from 0.04466
#  71/662 [==>...........................] - ETA: 6:35 - loss: 0.0471 - confidence_loss: 0.0029 - class_loss: 0.1002 - smooth_l1: 0.0248
# Epoch 7: loss did not improve from 0.04466
# 121/662 [====>.........................] - ETA: 6:02 - loss: 0.0464 - confidence_loss: 0.0029 - class_loss: 0.1003 - smooth_l1: 0.0248
# Epoch 7: loss did not improve from 0.04466
# 171/662 [======>.......................] - ETA: 5:28 - loss: 0.0461 - confidence_loss: 0.0029 - class_loss: 0.1005 - smooth_l1: 0.0248
# Epoch 7: loss did not improve from 0.04466
# 221/662 [=========>....................] - ETA: 4:55 - loss: 0.0464 - confidence_loss: 0.0028 - class_loss: 0.1004 - smooth_l1: 0.0250
# Epoch 7: loss did not improve from 0.04466
# 271/662 [===========>..................] - ETA: 4:22 - loss: 0.0455 - confidence_loss: 0.0028 - class_loss: 0.1005 - smooth_l1: 0.0251
# Epoch 7: loss did not improve from 0.04466
# 321/662 [=============>................] - ETA: 3:48 - loss: 0.0457 - confidence_loss: 0.0028 - class_loss: 0.1005 - smooth_l1: 0.0250
# Epoch 7: loss did not improve from 0.04466
# 371/662 [===============>..............] - ETA: 3:15 - loss: 0.0460 - confidence_loss: 0.0028 - class_loss: 0.1004 - smooth_l1: 0.0250
# Epoch 7: loss did not improve from 0.04466
# 421/662 [==================>...........] - ETA: 2:41 - loss: 0.0457 - confidence_loss: 0.0028 - class_loss: 0.1004 - smooth_l1: 0.0249
# Epoch 7: loss did not improve from 0.04466
# 471/662 [====================>.........] - ETA: 2:08 - loss: 0.0457 - confidence_loss: 0.0028 - class_loss: 0.1003 - smooth_l1: 0.0249
# Epoch 7: loss did not improve from 0.04466
# 521/662 [======================>.......] - ETA: 1:34 - loss: 0.0460 - confidence_loss: 0.0028 - class_loss: 0.1002 - smooth_l1: 0.0248
# Epoch 7: loss did not improve from 0.04466
# 571/662 [========================>.....] - ETA: 1:01 - loss: 0.0459 - confidence_loss: 0.0028 - class_loss: 0.1001 - smooth_l1: 0.0248
# Epoch 7: loss did not improve from 0.04466
# 621/662 [===========================>..] - ETA: 27s - loss: 0.0460 - confidence_loss: 0.0028 - class_loss: 0.1000 - smooth_l1: 0.0247
# Epoch 7: loss did not improve from 0.04466
# 662/662 [==============================] - 443s 669ms/step - loss: 0.0460 - confidence_loss: 0.0028 - class_loss: 0.1000 - smooth_l1: 0.0247
# Epoch 8/10
#   8/662 [..............................] - ETA: 7:18 - loss: 0.0474 - confidence_loss: 0.0028 - class_loss: 0.0981 - smooth_l1: 0.0257
# Epoch 8: loss did not improve from 0.04466
#  58/662 [=>............................] - ETA: 6:44 - loss: 0.0475 - confidence_loss: 0.0027 - class_loss: 0.0989 - smooth_l1: 0.0250
# Epoch 8: loss did not improve from 0.04466
# 108/662 [===>..........................] - ETA: 6:10 - loss: 0.0468 - confidence_loss: 0.0027 - class_loss: 0.0989 - smooth_l1: 0.0245
# Epoch 8: loss did not improve from 0.04466
# 158/662 [======>.......................] - ETA: 5:37 - loss: 0.0467 - confidence_loss: 0.0027 - class_loss: 0.0990 - smooth_l1: 0.0244
# Epoch 8: loss did not improve from 0.04466
# 208/662 [========>.....................] - ETA: 5:04 - loss: 0.0461 - confidence_loss: 0.0027 - class_loss: 0.0990 - smooth_l1: 0.0243
# Epoch 8: loss did not improve from 0.04466
# 258/662 [==========>...................] - ETA: 4:30 - loss: 0.0450 - confidence_loss: 0.0027 - class_loss: 0.0990 - smooth_l1: 0.0241
# Epoch 8: loss did not improve from 0.04466
# 308/662 [============>.................] - ETA: 3:57 - loss: 0.0444 - confidence_loss: 0.0027 - class_loss: 0.0990 - smooth_l1: 0.0241
# Epoch 8: loss improved from 0.04466 to 0.04444, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 358/662 [===============>..............] - ETA: 3:24 - loss: 0.0440 - confidence_loss: 0.0026 - class_loss: 0.0990 - smooth_l1: 0.0241
# Epoch 8: loss improved from 0.04444 to 0.04394, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 408/662 [=================>............] - ETA: 2:51 - loss: 0.0444 - confidence_loss: 0.0027 - class_loss: 0.0989 - smooth_l1: 0.0240
# Epoch 8: loss did not improve from 0.04394
# 458/662 [===================>..........] - ETA: 2:17 - loss: 0.0442 - confidence_loss: 0.0027 - class_loss: 0.0988 - smooth_l1: 0.0240
# Epoch 8: loss did not improve from 0.04394
# 508/662 [======================>.......] - ETA: 1:43 - loss: 0.0441 - confidence_loss: 0.0027 - class_loss: 0.0988 - smooth_l1: 0.0239
# Epoch 8: loss did not improve from 0.04394
# 558/662 [========================>.....] - ETA: 1:10 - loss: 0.0444 - confidence_loss: 0.0027 - class_loss: 0.0987 - smooth_l1: 0.0239
# Epoch 8: loss did not improve from 0.04394
# 608/662 [==========================>...] - ETA: 36s - loss: 0.0450 - confidence_loss: 0.0027 - class_loss: 0.0986 - smooth_l1: 0.0239
# Epoch 8: loss did not improve from 0.04394
# 658/662 [============================>.] - ETA: 2s - loss: 0.0450 - confidence_loss: 0.0027 - class_loss: 0.0985 - smooth_l1: 0.0239
# Epoch 8: loss did not improve from 0.04394
# 662/662 [==============================] - 445s 672ms/step - loss: 0.0450 - confidence_loss: 0.0027 - class_loss: 0.0985 - smooth_l1: 0.0239
# Epoch 9/10
#  45/662 [=>............................] - ETA: 6:52 - loss: 0.0471 - confidence_loss: 0.0026 - class_loss: 0.0976 - smooth_l1: 0.0235
# Epoch 9: loss did not improve from 0.04394
#  95/662 [===>..........................] - ETA: 6:19 - loss: 0.0418 - confidence_loss: 0.0025 - class_loss: 0.0976 - smooth_l1: 0.0235
# Epoch 9: loss improved from 0.04394 to 0.04165, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
# 145/662 [=====>........................] - ETA: 5:48 - loss: 0.0421 - confidence_loss: 0.0026 - class_loss: 0.0978 - smooth_l1: 0.0236
# Epoch 9: loss did not improve from 0.04165
# 195/662 [=======>......................] - ETA: 5:14 - loss: 0.0435 - confidence_loss: 0.0026 - class_loss: 0.0980 - smooth_l1: 0.0237
# Epoch 9: loss did not improve from 0.04165
# 245/662 [==========>...................] - ETA: 4:40 - loss: 0.0437 - confidence_loss: 0.0026 - class_loss: 0.0981 - smooth_l1: 0.0237
# Epoch 9: loss did not improve from 0.04165
# 295/662 [============>.................] - ETA: 4:06 - loss: 0.0433 - confidence_loss: 0.0026 - class_loss: 0.0981 - smooth_l1: 0.0237
# Epoch 9: loss did not improve from 0.04165
# 345/662 [==============>...............] - ETA: 3:33 - loss: 0.0427 - confidence_loss: 0.0025 - class_loss: 0.0981 - smooth_l1: 0.0236
# Epoch 9: loss did not improve from 0.04165
# 395/662 [================>.............] - ETA: 2:59 - loss: 0.0426 - confidence_loss: 0.0025 - class_loss: 0.0981 - smooth_l1: 0.0236
# Epoch 9: loss did not improve from 0.04165
# 445/662 [===================>..........] - ETA: 2:25 - loss: 0.0425 - confidence_loss: 0.0025 - class_loss: 0.0980 - smooth_l1: 0.0235
# Epoch 9: loss did not improve from 0.04165
# 495/662 [=====================>........] - ETA: 1:52 - loss: 0.0429 - confidence_loss: 0.0025 - class_loss: 0.0979 - smooth_l1: 0.0235
# Epoch 9: loss did not improve from 0.04165
# 545/662 [=======================>......] - ETA: 1:18 - loss: 0.0425 - confidence_loss: 0.0025 - class_loss: 0.0979 - smooth_l1: 0.0235
# Epoch 9: loss did not improve from 0.04165
# 595/662 [=========================>....] - ETA: 45s - loss: 0.0422 - confidence_loss: 0.0025 - class_loss: 0.0978 - smooth_l1: 0.0234
# Epoch 9: loss did not improve from 0.04165
# 645/662 [============================>.] - ETA: 11s - loss: 0.0424 - confidence_loss: 0.0025 - class_loss: 0.0978 - smooth_l1: 0.0234
# Epoch 9: loss did not improve from 0.04165
# 662/662 [==============================] - 444s 670ms/step - loss: 0.0423 - confidence_loss: 0.0025 - class_loss: 0.0978 - smooth_l1: 0.0234
# Epoch 10/10
#  32/662 [>.............................] - ETA: 7:01 - loss: 0.0332 - confidence_loss: 0.0024 - class_loss: 0.0974 - smooth_l1: 0.0237
# Epoch 10: loss improved from 0.04165 to 0.03303, saving model to /content/drive/MyDrive/fish/fishdetector_wh_upd.hdf5
#  82/662 [==>...........................] - ETA: 6:32 - loss: 0.0377 - confidence_loss: 0.0024 - class_loss: 0.0971 - smooth_l1: 0.0234
# Epoch 10: loss did not improve from 0.03303
# 132/662 [====>.........................] - ETA: 5:56 - loss: 0.0377 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0229
# Epoch 10: loss did not improve from 0.03303
# 182/662 [=======>......................] - ETA: 5:22 - loss: 0.0396 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0231
# Epoch 10: loss did not improve from 0.03303
# 232/662 [=========>....................] - ETA: 4:48 - loss: 0.0393 - confidence_loss: 0.0024 - class_loss: 0.0968 - smooth_l1: 0.0231
# Epoch 10: loss did not improve from 0.03303
# 282/662 [===========>..................] - ETA: 4:14 - loss: 0.0398 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0230
# Epoch 10: loss did not improve from 0.03303
# 332/662 [==============>...............] - ETA: 3:41 - loss: 0.0399 - confidence_loss: 0.0024 - class_loss: 0.0968 - smooth_l1: 0.0231
# Epoch 10: loss did not improve from 0.03303
# 382/662 [================>.............] - ETA: 3:07 - loss: 0.0408 - confidence_loss: 0.0024 - class_loss: 0.0968 - smooth_l1: 0.0231
# Epoch 10: loss did not improve from 0.03303
# 432/662 [==================>...........] - ETA: 2:34 - loss: 0.0403 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0231
# Epoch 10: loss did not improve from 0.03303
# 482/662 [====================>.........] - ETA: 2:00 - loss: 0.0400 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0230
# Epoch 10: loss did not improve from 0.03303
# 532/662 [=======================>......] - ETA: 1:27 - loss: 0.0407 - confidence_loss: 0.0024 - class_loss: 0.0968 - smooth_l1: 0.0229
# Epoch 10: loss did not improve from 0.03303
# 582/662 [=========================>....] - ETA: 53s - loss: 0.0407 - confidence_loss: 0.0024 - class_loss: 0.0968 - smooth_l1: 0.0228
# Epoch 10: loss did not improve from 0.03303
# 632/662 [===========================>..] - ETA: 20s - loss: 0.0407 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0228
# Epoch 10: loss did not improve from 0.03303
# 662/662 [==============================] - 444s 670ms/step - loss: 0.0411 - confidence_loss: 0.0024 - class_loss: 0.0967 - smooth_l1: 0.0227
